# %%
#-*- coding: utf-8 -*-
import math
import os
#import ipdb
import tensorflow as tf
import numpy as np
import pandas as pd
import pickle

from tensorflow.models.rnn import rnn_cell
import tensorflow.python.platform
from keras.preprocessing import sequence

# %%
class Caption_Generator():

    def init_weight(self, dim_in, dim_out, name=None, stddev=1.0):
        return tf.Variable(tf.truncated_normal([dim_in, dim_out], stddev=stddev/math.sqrt(float(dim_in))), name=name)

    def init_bias(self, dim_out, name=None):
        return tf.Variable(tf.zeros([dim_out]), name=name)

    def __init__(self, n_words, dim_embed, dim_ctx, dim_hidden, n_lstm_steps, batch_size=200, ctx_shape=[196,512], bias_init_vector=None):
        self.n_words = n_words
        self.dim_embed = dim_embed
        self.dim_ctx = dim_ctx
        self.dim_hidden = dim_hidden
        self.ctx_shape = ctx_shape
        self.n_lstm_steps = n_lstm_steps
        self.batch_size = batch_size

        with tf.device("/cpu:0"):
            self.Wemb = tf.Variable(tf.random_uniform([n_words, dim_embed], -1.0, 1.0), name='Wemb')

        self.init_hidden_W = self.init_weight(dim_ctx, dim_hidden, name='init_hidden_W')
        self.init_hidden_b = self.init_bias(dim_hidden, name='init_hidden_b')

        self.init_memory_W = self.init_weight(dim_ctx, dim_hidden, name='init_memory_W')
        self.init_memory_b = self.init_bias(dim_hidden, name='init_memory_b')

        self.lstm_W = self.init_weight(dim_embed, dim_hidden*4, name='lstm_W')
        self.lstm_U = self.init_weight(dim_hidden, dim_hidden*4, name='lstm_U')
        self.lstm_b = self.init_bias(dim_hidden*4, name='lstm_b')

        self.image_encode_W = self.init_weight(dim_ctx, dim_hidden*4, name='image_encode_W')

        self.image_att_W = self.init_weight(dim_ctx, dim_ctx, name='image_att_W')
        self.hidden_att_W = self.init_weight(dim_hidden, dim_ctx, name='hidden_att_W')
        self.pre_att_b = self.init_bias(dim_ctx, name='pre_att_b')

        self.att_W = self.init_weight(dim_ctx, 1, name='att_W')
        self.att_b = self.init_bias(1, name='att_b')

        self.decode_lstm_W = self.init_weight(dim_hidden, dim_embed, name='decode_lstm_W')
        self.decode_lstm_b = self.init_bias(dim_embed, name='decode_lstm_b')

        self.decode_word_W = self.init_weight(dim_embed, n_words, name='decode_word_W')

        if bias_init_vector is not None:
            self.decode_word_b = tf.Variable(bias_init_vector.astype(np.float32), name='decode_word_b')
        else:
            self.decode_word_b = self.init_bias(n_words, name='decode_word_b')


    def get_initial_lstm(self, mean_context):
        initial_hidden = tf.nn.tanh(tf.matmul(mean_context, self.init_hidden_W) + self.init_hidden_b)
        initial_memory = tf.nn.tanh(tf.matmul(mean_context, self.init_memory_W) + self.init_memory_b)

        return initial_hidden, initial_memory

    def build_model(self):
        context = tf.placeholder("float32", [self.batch_size, self.ctx_shape[0], self.ctx_shape[1]])
        sentence = tf.placeholder("int32", [self.batch_size, self.n_lstm_steps])
        mask = tf.placeholder("float32", [self.batch_size, self.n_lstm_steps])

        h, c = self.get_initial_lstm(tf.reduce_mean(context, 1))

        # TensorFlow가 dot(3D tensor, matrix) 계산을 못함;;; ㅅㅂ 삽질 ㄱㄱ
        context_flat = tf.reshape(context, [-1, self.dim_ctx])
        context_encode = tf.matmul(context_flat, self.image_att_W) # (batch_size, 196, 512)
        context_encode = tf.reshape(context_encode, [-1, ctx_shape[0], ctx_shape[1]])

        loss = 0.0

        for ind in range(self.n_lstm_steps):

            if ind == 0:
                word_emb = tf.zeros([self.batch_size, self.dim_embed])
            else:
                tf.get_variable_scope().reuse_variables()
                with tf.device("/cpu:0"):
                    word_emb = tf.nn.embedding_lookup(self.Wemb, sentence[:,ind-1])

            x_t = tf.matmul(word_emb, self.lstm_W) + self.lstm_b # (batch_size, hidden*4)

            labels = tf.expand_dims(sentence[:,ind], 1)
            indices = tf.expand_dims(tf.range(0, self.batch_size, 1), 1)
            concated = tf.concat(1, [indices, labels])
            onehot_labels = tf.sparse_to_dense( concated, tf.pack([self.batch_size, self.n_words]), 1.0, 0.0)

            context_encode = context_encode + \
                 tf.expand_dims(tf.matmul(h, self.hidden_att_W), 1) + \
                 self.pre_att_b

            context_encode = tf.nn.tanh(context_encode)

            # 여기도 context_encode: 3D -> flat required
            context_encode_flat = tf.reshape(context_encode, [-1, self.dim_ctx]) # (batch_size*196, 512)
            alpha = tf.matmul(context_encode_flat, self.att_W) + self.att_b # (batch_size*196, 1)
            alpha = tf.reshape(alpha, [-1, self.ctx_shape[0]])
            alpha = tf.nn.softmax( alpha )

            weighted_context = tf.reduce_sum(context * tf.expand_dims(alpha, 2), 1)

            lstm_preactive = tf.matmul(h, self.lstm_U) + x_t + tf.matmul(weighted_context, self.image_encode_W)
            i, f, o, new_c = tf.split(1, 4, lstm_preactive)

            i = tf.nn.sigmoid(i)
            f = tf.nn.sigmoid(f)
            o = tf.nn.sigmoid(o)
            new_c = tf.nn.tanh(new_c)

            c = f * c + i * new_c
            h = o * tf.nn.tanh(new_c)

            logits = tf.matmul(h, self.decode_lstm_W) + self.decode_lstm_b
            logits = tf.nn.relu(logits)
            logits = tf.nn.dropout(logits, 0.5)

            logit_words = tf.matmul(logits, self.decode_word_W) + self.decode_word_b
            cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logit_words, onehot_labels)
            cross_entropy = cross_entropy * mask[:,ind]

            current_loss = tf.reduce_sum(cross_entropy)
            loss = loss + current_loss

        loss = loss / tf.reduce_sum(mask)
        return loss, context, sentence, mask

    def build_generator(self, maxlen):
        context = tf.placeholder("float32", [1, self.ctx_shape[0], self.ctx_shape[1]])
        h, c = self.get_initial_lstm(tf.reduce_mean(context, 1))
        
        #print(context[0].shape)
        #context_encode = tf.matmul(context[0], self.image_att_W)
        context_encode = tf.matmul(tf.squeeze(context,[0]), self.image_att_W)
        generated_words = []
        logit_list = []
        alpha_list = []
        word_emb = tf.zeros([1, self.dim_embed])
        for ind in range(maxlen):
            x_t = tf.matmul(word_emb, self.lstm_W) + self.lstm_b
            context_encode = context_encode + tf.matmul(h, self.hidden_att_W) + self.pre_att_b
            context_encode = tf.nn.tanh(context_encode)

            alpha = tf.matmul(context_encode, self.att_W) + self.att_b
            alpha = tf.reshape(alpha, [-1, self.ctx_shape[0]] )
            alpha = tf.nn.softmax(alpha)

            alpha = tf.reshape(alpha, (ctx_shape[0], -1))
            alpha_list.append(alpha)

            weighted_context = tf.reduce_sum(tf.squeeze(context) * alpha, 0)
            weighted_context = tf.expand_dims(weighted_context, 0)

            lstm_preactive = tf.matmul(h, self.lstm_U) + x_t + tf.matmul(weighted_context, self.image_encode_W)

            i, f, o, new_c = tf.split(1, 4, lstm_preactive)

            i = tf.nn.sigmoid(i)
            f = tf.nn.sigmoid(f)
            o = tf.nn.sigmoid(o)
            new_c = tf.nn.tanh(new_c)

            c = f*c + i*new_c
            h = o*tf.nn.tanh(new_c)

            logits = tf.matmul(h, self.decode_lstm_W) + self.decode_lstm_b
            logits = tf.nn.relu(logits)

            logit_words = tf.matmul(logits, self.decode_word_W) + self.decode_word_b

            max_prob_word = tf.argmax(logit_words, 1)

            with tf.device("/cpu:0"):
                word_emb = tf.nn.embedding_lookup(self.Wemb, max_prob_word)

            generated_words.append(max_prob_word)
            logit_list.append(logit_words)

        return context, generated_words, logit_list, alpha_list

# %%
###### 학습 관련 Parameters ######
n_epochs=20
batch_size=10
dim_embed=256
dim_ctx=2048
dim_hidden=256
ctx_shape=[1,2048]
#############################
###### 잡다한 Parameters #####
annotation_path = 'test_data/caption/caption.p'
feat_path = 'test_data/features/features.p'
model_path = 'test_data/model/'
#############################

# %%
def preProBuildWordVocab(sentence_iterator, word_count_threshold=0): # borrowed this function from NeuralTalk
    print 'preprocessing word counts and creating vocab based on word count threshold %d' % (word_count_threshold, )
    word_counts = {}
    nsents = 0
    for sent in sentence_iterator:
        nsents += 1
        for w in sent.lower().split(' '):
            word_counts[w] = word_counts.get(w, 0) + 1
    vocab = [w for w in word_counts if word_counts[w] >= word_count_threshold]
    print 'filtered words from %d to %d' % (len(word_counts), len(vocab))

    ixtoword = {}
    ixtoword[0] = '#END#'  # end token at the end of the sentence. make first dimension be end token
    wordtoix = {}
    wordtoix['#START#'] = 0 # make first vector be the start token
    ix = 1
    for w in vocab:
        wordtoix[w] = ix
        ixtoword[ix] = w
        ix += 1

    word_counts['#END#'] = nsents
    bias_init_vector = np.array([1.0*word_counts[ixtoword[i]] for i in ixtoword])
    bias_init_vector /= np.sum(bias_init_vector) # normalize to frequencies
    bias_init_vector = np.log(bias_init_vector)
    bias_init_vector -= np.max(bias_init_vector) # shift to nice numeric range
    return wordtoix, ixtoword, bias_init_vector

# %%
def train(pretrained_model_path=None): # 전에 학습하던게 있으면 초기값 설정.
    annotation_data = pickle.load(open(annotation_path,"rb"))
    captions = annotation_data.values()
    wordtoix, ixtoword, bias_init_vector = preProBuildWordVocab(captions)

    learning_rate=0.001
    n_words = len(wordtoix)
    feats = np.load(feat_path)
    maxlen = np.max( map(lambda x: len(x.split(' ')), captions) )

    sess = tf.InteractiveSession()

    caption_generator = Caption_Generator(
            n_words=n_words,
            dim_embed=dim_embed,
            dim_ctx=dim_ctx,
            dim_hidden=dim_hidden,
            n_lstm_steps=maxlen+1, # w1~wN까지 예측한 뒤 마지막에 '.'예측해야하니까 +1
            batch_size=batch_size,
            ctx_shape=ctx_shape,
            bias_init_vector=bias_init_vector)

    loss, context, sentence, mask = caption_generator.build_model()
    saver = tf.train.Saver(max_to_keep=50)

    
    train_op = tf.train.AdamOptimizer(learning_rate).minimize(loss)
    tf.initialize_all_variables().run()
    if pretrained_model_path is not None:
        print "Starting with pretrained model"
        saver.restore(sess, pretrained_model_path)

    index = annotation_data.keys()
    #np.random.shuffle(index)
    #annotation_data = annotation_data.ix[index]

    #captions = annotation_data['caption'].values
    image_id = annotation_data.keys()
                                  

    for epoch in range(n_epochs):
        for start, end in zip( \
                range(0, len(captions), batch_size),
                range(batch_size, len(captions), batch_size)):

            current_feats = np.array([feats[x] for x in image_id[start:end] ])
            current_feats = current_feats.reshape(-1, ctx_shape[1], ctx_shape[0]).swapaxes(1,2)

            current_captions = captions[start:end]
            current_caption_ind = map(lambda cap: [wordtoix[word] for word in cap.lower().split(' ') if word in wordtoix], current_captions) # '.'은 제거

            current_caption_matrix = sequence.pad_sequences(current_caption_ind, padding='post', maxlen=maxlen+1)

            current_mask_matrix = np.zeros((current_caption_matrix.shape[0], current_caption_matrix.shape[1]))
            nonzeros = np.array( map(lambda x: (x != 0).sum()+1, current_caption_matrix ))

            for ind, row in enumerate(current_mask_matrix):
                row[:nonzeros[ind]] = 1

            _, loss_value = sess.run([train_op, loss], feed_dict={
                context:current_feats,
                sentence:current_caption_matrix,
                mask:current_mask_matrix})

            print "Current Cost: ", loss_value
        saver.save(sess, os.path.join(model_path, 'model'), global_step=epoch)

# %%
train()
# Out:
# preprocessing word counts and creating vocab based on word count threshold 0
# filtered words from 1362 to 1362
# Current Cost:  5.95207
# Current Cost:  5.93166
# Current Cost:  6.08734
# Current Cost:  5.88682
# Current Cost:  5.87856
# Current Cost:  6.04123
# Current Cost:  5.82217
# Current Cost:  5.83254
# Current Cost:  5.99621
# Current Cost:  5.73161
# Current Cost:  5.74907
# Current Cost:  5.91648
# Current Cost:  5.61307
# Current Cost:  5.64981
# Current Cost:  5.84658
# Current Cost:  5.47984
# Current Cost:  5.53602
# Current Cost:  5.74666
# Current Cost:  5.35424
# Current Cost:  5.42488
# Current Cost:  5.65145
# Current Cost:  5.25038
# Current Cost:  5.28652
# Current Cost:  5.53271
# Current Cost:  5.07735
# Current Cost:  5.17238
# Current Cost:  5.41019
# Current Cost:  4.91598
# Current Cost:  5.02622
# Current Cost:  5.29289
# Current Cost:  4.74671
# Current Cost:  4.91005
# Current Cost:  5.16346
# Current Cost:  4.61152
# Current Cost:  4.79217
# Current Cost:  5.04249
# Current Cost:  4.56163
# Current Cost:  4.59395
# Current Cost:  5.04366
# Current Cost:  4.33797
# Current Cost:  4.54404
# Current Cost:  4.81628
# Current Cost:  4.16467
# Current Cost:  4.2894
# Current Cost:  4.64459
# Current Cost:  4.07412
# Current Cost:  4.1672
# Current Cost:  4.53389
# Current Cost:  3.83381
# Current Cost:  4.02898
# Current Cost:  4.36071
# Current Cost:  3.72477
# Current Cost:  3.88715
# Current Cost:  4.22374
# Current Cost:  3.53249
# Current Cost:  3.70289
# Current Cost:  4.06485
# Current Cost:  3.37538
# Current Cost:  3.54445
# Current Cost:  3.90695

# %%
def test(test_feat="test_data/features/test_feat.p", model_path='test_data/model/model-19', maxlen=500):
    annotation_data = pickle.load(open(annotation_path,"rb"))
    captions = annotation_data.values()
    wordtoix, ixtoword, bias_init_vector = preProBuildWordVocab(captions)
    n_words = len(wordtoix)
    feat = np.load(test_feat)
    feat = np.array([feat[x] for x in ['200744']])
    feat = feat.reshape(-1, ctx_shape[1], ctx_shape[0]).swapaxes(1,2)

    sess = tf.InteractiveSession()

    caption_generator = Caption_Generator(
            n_words=n_words,
            dim_embed=dim_embed,
            dim_ctx=dim_ctx,
            dim_hidden=dim_hidden,
            n_lstm_steps=maxlen,
            batch_size=batch_size,
            ctx_shape=ctx_shape)

    context, generated_words, logit_list, alpha_list = caption_generator.build_generator(maxlen=maxlen)
    saver = tf.train.Saver()
    saver.restore(sess, model_path)
    print("Model Restored")

    generated_word_index = sess.run(generated_words, feed_dict={context:feat})
    #alpha_list_val = sess.run(alpha_list, feed_dict={context:feat})
    generated_words = [ixtoword[x[0]] for x in generated_word_index]
    #punctuation = np.argmax(np.array(generated_words) == '.')+1

    #generated_words = generated_words[:punctuation]
    #alpha_list_val = alpha_list_val[:punctuation]
    return generated_words

# %%
generated_words = test()
print(' '.join(generated_words))
# Out:
# preprocessing word counts and creating vocab based on word count threshold 0
# u'2'
# u'fresh'
# u'poblano'
# u'chile'
# u'peppers\n2'
# u'serrano'
# u'chile'
# u'peppers\n6'
# u'fresh'
# u'tomatillos,'
# u'husks'
# u'removed\n1'
# u'1/2-inch'
# u'slice'
# u'of'
# u'white'
# u'onion\n2'
# u'cloves'
# u'garlic\nsalt'
# u'to'
# u'taste\n1'
# u'tablespoon'
# u'chopped'
# u'fresh'
# u'cilantro'
# u'(optional)\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\npreheat'
# u'an'
# u'outdoor'
# u'grill'
# u'for'
# u'high'
# u'heat,'
# u'and'
# u'lightly'
# u'oil'
# u'the'
# u'grate.\nlay'
# u'the'
# u'poblano'
# u'peppers,'
# u'serrano'
# u'peppers,'
# u'and'
# u'tomatillos'
# u'on'
# u'the'
# u'hot'
# u'grill,'
# u'and'
# u'cook,'
# u'turning'
# u'every'
# u'2'
# u'minutes,'
# u'until'
# u'the'
# u'pepper'
# u'skins'
# u'are'
# u'evenly'
# u'charred'
# u'and'
# u'blackened,'
# u'and'
# u'the'
# u'tomatillos'
# u'have'
# u'turned'
# u'pale'
# u'yellow'
# u'and'
# u'started'
# u'to'
# u'ooze'
# u'juice,'
# u'about'
# u'10'
# u'minutes.'
# u'remove'
# u'the'
# u'vegetables'
# u'from'
# u'the'
# u'grill.\nscrape'
# u'off'
# u'most'
# u'of'
# u'the'
# u'burned'
# u'pepper'
# u'skin,'
# u'cut'
# u'the'
# u'stems'
# u'off,'
# u'cut'
# u'the'
# u'peppers'
# u'in'
# u'half'
# u'the'
# u'long'
# u'way,'
# u'and'
# u'remove'
# u'the'
# u'seeds.\nplace'
# u'the'
# u'onion'
# u'and'
# u'garlic'
# u'in'
# u'the'
# u'work'
# u'bowl'
# u'of'
# u'a'
# u'food'
# u'processor,'
# u'and'
# u'pulse'
# u'about'
# u'4'
# u'times'
# u'to'
# u'chop.'
# u'drop'
# u'in'
# u'the'
# u'peppers,'
# u'pulse'
# u'4'
# u'times'
# u'to'
# u'roughly'
# u'chop,'
# u'and'
# u'add'
# u'the'
# u'tomatillos'
# u'and'
# u'salt.'
# u'pulse'
# u'4'
# u'or'
# u'more'
# u'times'
# u'to'
# u'the'
# u'desired'
# u'smoothness,'
# u'and'
# u'stir'
# u'in'
# u'the'
# u'cilantro.\n'
# u'1'
# u'pound'
# u'chicken'
# u'livers\n1'
# u'egg\n1/2'
# u'cup'
# u'milk\n1'
# u'cup'
# u'all-purpose'
# u'flour\n1'
# u'tablespoon'
# u'garlic'
# u'powder\nsalt'
# u'and'
# u'pepper'
# u'to'
# u'taste\n1'
# u'quart'
# u'vegetable'
# u'oil'
# u'for'
# u'frying\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nplace'
# u'the'
# u'chicken'
# u'livers'
# u'in'
# u'a'
# u'colander,'
# u'and'
# u'rinse'
# u'with'
# u'water.'
# u'drain'
# u'the'
# u'livers'
# u'well.'
# u'whisk'
# u'together'
# u'the'
# u'egg'
# u'and'
# u'milk'
# u'in'
# u'a'
# u'shallow'
# u'bowl'
# u'until'
# u'well'
# u'blended.'
# u'place'
# u'the'
# u'flour,'
# u'garlic'
# u'powder,'
# u'and'
# u'salt'
# u'and'
# u'pepper'
# u'in'
# u'a'
# u'resealable'
# u'plastic'
# u'zipper'
# u'bag,'
# u'and'
# u'shake'
# u'to'
# u'combine.\nheat'
# u'oil'
# u'in'
# u'a'
# u'deep-fryer'
# u'or'
# u'large'
# u'saucepan'
# u'to'
# u'375'
# u'degrees'
# u'f'
# u'(190'
# u'degrees'
# u'c).\nplace'
# u'the'
# u'chicken'
# u'livers'
# u'in'
# u'the'
# u'bowl'
# u'of'
# u'egg'
# u'and'
# u'milk'
# u'mixture,'
# u'and'
# u'coat'
# u'each'
# u'liver.'
# u'place'
# u'the'
# u'livers,'
# u'one'
# u'at'
# u'a'
# u'time,'
# u'into'
# u'the'
# u'plastic'
# u'bag'
# u'of'
# u'flour'
# u'mixture,'
# u'and'
# u'shake'
# u'the'
# u'bag'
# u'to'
# u'coat'
# u'the'
# u'each'
# u'liver'
# u'completely.\ngently'
# u'place'
# u'the'
# u'coated'
# u'livers,'
# u'a'
# u'few'
# u'at'
# u'a'
# u'time,'
# u'into'
# u'the'
# u'hot'
# u'oil.'
# u'cover'
# u'the'
# u'pan'
# u'of'
# u'oil'
# u'with'
# u'a'
# u'frying'
# u'screen'
# u'to'
# u'avoid'
# u'getting'
# u'burned'
# u'by'
# u'spatters'
# u'of'
# u'oil'
# u'that'
# u'will'
# u'pop'
# u'out'
# u'as'
# u'the'
# u'livers'
# u'fry.'
# u'deep'
# u'fry'
# u'the'
# u'livers'
# u'until'
# u'crisp'
# u'and'
# u'golden'
# u'brown,'
# u'5'
# u'to'
# u'6'
# u'minutes.\n'
# u'4'
# u'pork'
# u'chops\n1'
# u'tablespoon'
# u'butter\n1/2'
# u'cup'
# u'brown'
# u'sugar\n3/4'
# u'cup'
# u'evaporated'
# u'milk\n1/4'
# u'cup'
# u'light'
# u'corn'
# u'syrup\n1/4'
# u'cup'
# u'chopped'
# u'pecans\nin'
# u'a'
# u'large'
# u'skillet'
# u'over'
# u'medium-high'
# u'heat,'
# u'cook'
# u'the'
# u'pork'
# u'chops'
# u'until'
# u'no'
# u'longer'
# u'pink'
# u'in'
# u'the'
# u'center,'
# u'5'
# u'to'
# u'7'
# u'minutes'
# u'per'
# u'side.'
# u'an'
# u'instant-read'
# u'thermometer'
# u'inserted'
# u'into'
# u'the'
# u'center'
# u'should'
# u'read'
# u'145'
# u'degrees'
# u'f'
# u'(63'
# u'degrees'
# u'c).\nmelt'
# u'the'
# u'butter'
# u'in'
# u'a'
# u'saucepan;'
# u'stir'
# u'the'
# u'brown'
# u'sugar'
# u'into'
# u'the'
# u'melted'
# u'butter'
# u'until'
# u'smooth.'
# u'add'
# u'the'
# u'evaporated'
# u'milk'
# u'and'
# u'stir;'
# u'bring'
# u'the'
# u'mixture'
# u'to'
# u'a'
# u'boil'
# u'and'
# u'immediately'
# u'remove'
# u'from'
# u'heat.'
# u'stir'
# u'the'
# u'corn'
# u'syrup'
# u'into'
# u'the'
# u'milk'
# u'mixture;'
# u'fold'
# u'the'
# u'pecans'
# u'into'
# u'the'
# u'sauce.'
# u'spoon'
# u'the'
# u'sauce'
# u'over'
# u'the'
# u'pork'
# u'chops'
# u'to'
# u'serve.\n'
# u'1'
# u'cup'
# u'soy'
# u'sauce\n1'
# u'cup'
# u'brown'
# u'sugar\n1'
# u'cup'
# u'water\n4'
# u'cloves'
# u'garlic,'
# u'minced\n1'
# u'onion,'
# u'chopped\n1'
# u'tablespoon'
# u'grated'
# u'fresh'
# u'ginger'
# u'root\n1'
# u'tablespoon'
# u'ground'
# u'black'
# u'pepper\n1'
# u'tablespoon'
# u'dried'
# u'oregano\n1'
# u'teaspoon'
# u'crushed'
# u'red'
# u'pepper'
# u'flakes'
# u'(optional)\n1'
# u'teaspoon'
# u'ground'
# u'cayenne'
# u'pepper'
# u'(optional)\n1'
# u'teaspoon'
# u'ground'
# u'paprika'
# u'(optional)\n5'
# u'pounds'
# u'skinless'
# u'chicken'
# u'thighs\nwhisk'
# u'together'
# u'the'
# u'soy'
# u'sauce,'
# u'brown'
# u'sugar,'
# u'water,'
# u'garlic,'
# u'onion,'
# u'ginger,'
# u'black'
# u'pepper,'
# u'oregano,'
# u'red'
# u'pepper'
# u'flakes,'
# u'cayenne'
# u'pepper,'
# u'and'
# u'paprika'
# u'in'
# u'a'
# u'large'
# u'glass'
# u'or'
# u'ceramic'
# u'bowl.'
# u'add'
# u'the'
# u'chicken'
# u'thighs,'
# u'and'
# u'toss'
# u'to'
# u'evenly'
# u'coat.'
# u'cover'
# u'the'
# u'bowl'
# u'with'
# u'plastic'
# u'wrap,'
# u'and'
# u'marinate'
# u'the'
# u'chicken'
# u'in'
# u'the'
# u'refrigerator'
# u'for'
# u'at'
# u'least'
# u'1'
# u'hour.\npreheat'
# u'an'
# u'outdoor'
# u'grill'
# u'for'
# u'medium'
# u'heat,'
# u'and'
# u'lightly'
# u'oil'
# u'the'
# u'grate.\nremove'
# u'the'
# u'chicken'
# u'thighs'
# u'from'
# u'the'
# u'marinade.'
# u'discard'
# u'the'
# u'remaining'
# u'marinade.'
# u'grill'
# u'the'
# u'chicken'
# u'thighs'
# u'on'
# u'the'
# u'preheated'
# u'grill'
# u'until'
# u'cooked'
# u'through,'
# u'about'
# u'15'
# u'minutes'
# u'per'
# u'side.\n'
# u'4'
# u'limes,'
# u'juiced\n2'
# u'tablespoons'
# u'olive'
# u'oil\n2'
# u'tablespoons'
# u'chili'
# u'powder\n1'
# u'teaspoon'
# u'dried'
# u'sage\n1'
# u'teaspoon'
# u'dried'
# u'oregano\n1'
# u'teaspoon'
# u'ground'
# u'cumin\n4'
# u'skinless,'
# u'boneless'
# u'chicken'
# u'breast'
# u'halves\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nwhisk'
# u'the'
# u'lime'
# u'juice,'
# u'olive'
# u'oil,'
# u'chili'
# u'powder,'
# u'sage,'
# u'oregano,'
# u'and'
# u'cumin'
# u'together'
# u'in'
# u'a'
# u'small'
# u'bowl.'
# u'arrange'
# u'the'
# u'chicken'
# u'breasts'
# u'in'
# u'a'
# u'shallow'
# u'glass'
# u'container;'
# u'pour'
# u'the'
# u'lime'
# u'juice'
# u'marinade'
# u'over'
# u'the'
# u'chicken.'
# u'cover'
# u'the'
# u'container'
# u'with'
# u'plastic'
# u'wrap;'
# u'refrigerate'
# u'1'
# u'1/2'
# u'hours,'
# u'turning'
# u'the'
# u'chicken'
# u'every'
# u'30'
# u'minutes.\npreheat'
# u'an'
# u'outdoor'
# u'grill'
# u'for'
# u'medium'
# u'heat'
# u'and'
# u'lightly'
# u'oil'
# u'the'
# u'grate.'
# u'remove'
# u'the'
# u'chicken'
# u'to'
# u'a'
# u'platter'
# u'and'
# u'allow'
# u'to'
# u'come'
# u'to'
# u'room'
# u'temperature.'
# u'pour'
# u'the'
# u'marinade'
# u'into'
# u'a'
# u'small'
# u'saucepan'
# u'and'
# u'bring'
# u'to'
# u'a'
# u'boil'
# u'over'
# u'high'
# u'heat.'
# u'reduce'
# u'heat'
# u'to'
# u'medium-low'
# u'and'
# u'simmer'
# u'for'
# u'10'
# u'minutes.\nbasting'
# u'with'
# u'the'
# u'marinade,'
# u'grill'
# u'the'
# u'chicken'
# u'breasts'
# u'until'
# u'no'
# u'longer'
# u'pink'
# u'in'
# u'the'
# u'center'
# u'and'
# u'the'
# u'juices'
# u'run'
# u'clear,'
# u'8'
# u'to'
# u'10'
# u'minutes'
# u'per'
# u'side.'
# u'an'
# u'instant-read'
# u'thermometer'
# u'inserted'
# u'into'
# u'the'
# u'center'
# u'should'
# u'read'
# u'at'
# u'least'
# u'165'
# u'degrees'
# u'f'
# u'(74'
# u'degrees'
# u'c).\n'
# u'10'
# u'ears'
# u'corn,'
# u'husked'
# u'and'
# u'cleaned\ncajun'
# u'seasoning'
# u'to'
# u'taste\nsalt'
# u'and'
# u'black'
# u'pepper'
# u'to'
# u'taste\n1'
# u'(1'
# u'pound)'
# u'package'
# u'sliced'
# u'bacon\n10'
# u'12x8-inch'
# u'sheets'
# u'aluminum'
# u'foil\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\npreheat'
# u'an'
# u'outdoor'
# u'grill'
# u'for'
# u'high'
# u'heat.\nsprinkle'
# u'each'
# u'ear'
# u'of'
# u'corn'
# u'with'
# u'cajun'
# u'seasoning,'
# u'salt,'
# u'and'
# u'pepper,'
# u'and'
# u'wrap'
# u'each'
# u'ear'
# u'with'
# u'2'
# u'slices'
# u'of'
# u'bacon,'
# u'covering'
# u'the'
# u'ear'
# u'as'
# u'completely'
# u'as'
# u'possible.'
# u'(a'
# u'big'
# u'ear'
# u'might'
# u'need'
# u'3'
# u'pieces'
# u'of'
# u'bacon.)'
# u'wrap'
# u'the'
# u'ears'
# u'in'
# u'aluminum'
# u'foil,'
# u'twisting'
# u'the'
# u'ends'
# u'tightly'
# u'to'
# u'seal.\nplace'
# u'the'
# u'wrapped'
# u'corn'
# u'on'
# u'the'
# u'preheated'
# u'grill,'
# u'and'
# u'grill'
# u'on'
# u'high'
# u'heat'
# u'until'
# u'the'
# u'corn'
# u'is'
# u'hot,'
# u'about'
# u'10'
# u'minutes'
# u'per'
# u'side.'
# u'turn'
# u'the'
# u'heat'
# u'to'
# u'low,'
# u'and'
# u'grill'
# u'the'
# u'corn'
# u'until'
# u'the'
# u'bacon'
# u'is'
# u'cooked'
# u'and'
# u'the'
# u'corn'
# u'is'
# u'tender,'
# u'about'
# u'45'
# u'minutes.\n'
# u'2'
# u'large'
# u'ripe'
# u'red'
# u'tomatoes,'
# u'sliced\n10'
# u'thin'
# u'slices'
# u'fresh'
# u'mozzarella'
# u'cheese\n10'
# u'fresh'
# u'basil'
# u'leaves,'
# u'chopped\n10'
# u'kalamata'
# u'olives\nextra'
# u'virgin'
# u'olive'
# u'oil\nsalt'
# u'to'
# u'taste\ncracked'
# u'black'
# u'pepper'
# u'to'
# u'taste\nalternate'
# u'and'
# u'overlap'
# u'the'
# u'tomato'
# u'slices'
# u'and'
# u'mozzarella'
# u'cheese'
# u'slices'
# u'on'
# u'a'
# u'platter.'
# u'sprinkle'
# u'the'
# u'basil'
# u'over'
# u'the'
# u'tomato'
# u'and'
# u'mozzarella'
# u'layers.'
# u'scatter'
# u'the'
# u'olives'
# u'over'
# u'the'
# u'salad.'
# u'drizzle'
# u'the'
# u'olive'
# u'oil'
# u'over'
# u'everything;'
# u'season'
# u'with'
# u'salt'
# u'and'
# u'pepper.'
# u'allow'
# u'to'
# u'sit'
# u'at'
# u'room'
# u'temperature'
# u'15'
# u'minutes'
# u'before'
# u'serving.\n'
# u'1'
# u'tablespoon'
# u'butter\n1/4'
# u'cup'
# u'chopped'
# u'red'
# u'shallots\n2'
# u'tablespoons'
# u'chopped'
# u'fresh'
# u'basil'
# u'leaves\n1'
# u'tablespoon'
# u'minced'
# u'fresh'
# u'garlic\n1'
# u'teaspoon'
# u'hot'
# u'paprika\n1'
# u'teaspoon'
# u'salt\n1'
# u'teaspoon'
# u'fresh'
# u'ground'
# u'black'
# u'pepper\n1'
# u'cup'
# u'fresh'
# u'spinach'
# u'leaves\n1/4'
# u'cup'
# u'diced'
# u'portabella'
# u'mushroom'
# u'caps\n1/4'
# u'cup'
# u'diced'
# u'yellow'
# u'bell'
# u'pepper\n1'
# u'tablespoon'
# u'sweet'
# u'jamaican'
# u'pepper'
# u'sauce'
# u'(such'
# u'as'
# u'pickapeppa'
# u'sauce'
# u'\xae)\n1'
# u'tablespoon'
# u'balsamic'
# u'vinegar\n1'
# u'hoagie'
# u'roll,'
# u'split'
# u'lengthwise\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nmelt'
# u'the'
# u'butter'
# u'in'
# u'a'
# u'skillet'
# u'with'
# u'a'
# u'lid'
# u'over'
# u'medium'
# u'heat,'
# u'and'
# u'cook'
# u'and'
# u'stir'
# u'the'
# u'red'
# u'shallots,'
# u'basil,'
# u'and'
# u'garlic'
# u'until'
# u'fragrant,'
# u'about'
# u'1'
# u'minute.'
# u'stir'
# u'in'
# u'the'
# u'hot'
# u'paprika,'
# u'salt,'
# u'and'
# u'pepper.'
# u'add'
# u'the'
# u'spinach,'
# u'portabella'
# u'mushrooms,'
# u'and'
# u'yellow'
# u'bell'
# u'pepper,'
# u'stir'
# u'a'
# u'few'
# u'times,'
# u'cover'
# u'with'
# u'lid,'
# u'and'
# u'reduce'
# u'the'
# u'heat'
# u'to'
# u'medium-low.'
# u'cook'
# u'the'
# u'mixture'
# u'until'
# u'the'
# u'spinach'
# u'and'
# u'mushrooms'
# u'give'
# u'up'
# u'their'
# u'liquid'
# u'and'
# u'the'
# u'peppers'
# u'are'
# u'softened,'
# u'about'
# u'4'
# u'minutes.\nuncover'
# u'the'
# u'skillet,'
# u'and'
# u'pour'
# u'in'
# u'the'
# u'pepper'
# u'sauce'
# u'and'
# u'balsamic'
# u'vinegar.'
# u'increase'
# u'the'
# u'heat'
# u'to'
# u'medium,'
# u'and'
# u'let'
# u'the'
# u'mixture'
# u'cook'
# u'down'
# u'and'
# u'thicken'
# u'slightly,'
# u'about'
# u'2'
# u'minutes.\nspoon'
# u'the'
# u'hot'
# u'mushroom'
# u'mixture'
# u'onto'
# u'the'
# u'split'
# u'hoagie'
# u'roll,'
# u'and'
# u'serve.\n'
# u'1'
# u'1/2'
# u'cups'
# u'baby'
# u'spinach'
# u'leaves\n3/4'
# u'cup'
# u'fresh'
# u'basil'
# u'leaves\n1/2'
# u'cup'
# u'toasted'
# u'pine'
# u'nuts\n1/2'
# u'cup'
# u'grated'
# u'parmesan'
# u'cheese\n4'
# u'cloves'
# u'garlic,'
# u'peeled'
# u'and'
# u'quartered\n3/4'
# u'teaspoon'
# u'kosher'
# u'salt\n1/2'
# u'teaspoon'
# u'freshly'
# u'ground'
# u'black'
# u'pepper\n1'
# u'tablespoon'
# u'fresh'
# u'lemon'
# u'juice\n1/2'
# u'teaspoon'
# u'lemon'
# u'zest\n1/2'
# u'cup'
# u'extra-virgin'
# u'olive'
# u'oil\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nblend'
# u'the'
# u'spinach,'
# u'basil,'
# u'pine'
# u'nuts,'
# u'parmesan'
# u'cheese,'
# u'garlic,'
# u'salt,'
# u'pepper,'
# u'lemon'
# u'juice,'
# u'lemon'
# u'zest,'
# u'and'
# u'2'
# u'tablespoons'
# u'olive'
# u'oil'
# u'in'
# u'a'
# u'food'
# u'processor'
# u'until'
# u'nearly'
# u'smooth,'
# u'scraping'
# u'the'
# u'sides'
# u'of'
# u'the'
# u'bowl'
# u'with'
# u'a'
# u'spatula'
# u'as'
# u'necessary.'
# u'drizzle'
# u'the'
# u'remaining'
# u'olive'
# u'oil'
# u'into'
# u'the'
# u'mixture'
# u'while'
# u'processing'
# u'until'
# u'smooth.\n'
# u'1'
# u'tablespoon'
# u'olive'
# u'oil\n1/2'
# u'red'
# u'onion,'
# u'diced\n2'
# u'cloves'
# u'garlic,'
# u'minced\n4'
# u'peaches'
# u'-'
# u'pitted'
# u'and'
# u'diced\n1'
# u'pear'
# u'-'
# u'peeled,'
# u'cored,'
# u'and'
# u'diced\n1/4'
# u'cup'
# u'honey\n1'
# u'teaspoon'
# u'curry'
# u'powder\nsalt'
# u'and'
# u'pepper'
# u'to'
# u'taste\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nheat'
# u'the'
# u'olive'
# u'oil'
# u'in'
# u'a'
# u'small'
# u'skillet'
# u'over'
# u'medium-low'
# u'heat;'
# u'cook'
# u'the'
# u'onion'
# u'and'
# u'garlic'
# u'in'
# u'the'
# u'hot'
# u'oil'
# u'until'
# u'translucent,'
# u'about'
# u'5'
# u'minutes.'
# u'stir'
# u'the'
# u'peaches,'
# u'pear,'
# u'and'
# u'honey'
# u'into'
# u'the'
# u'onion'
# u'and'
# u'garlic'
# u'mixture;'
# u'allow'
# u'to'
# u'cook'
# u'together'
# u'for'
# u'2'
# u'minutes.'
# u'season'
# u'with'
# u'the'
# u'curry'
# u'powder,'
# u'salt,'
# u'and'
# u'pepper.'
# u'continue'
# u'cooking'
# u'at'
# u'a'
# u'simmer'
# u'until'
# u'hot,'
# u'5'
# u'to'
# u'6'
# u'minutes.\n'
# u'2'
# u'eggs\n3/4'
# u'teaspoon'
# u'vanilla'
# u'extract\n1'
# u'tablespoon'
# u'ground'
# u'cinnamon\n2'
# u'1/4'
# u'teaspoons'
# u'white'
# u'sugar\n2'
# u'slices'
# u'bread\n1'
# u'banana,'
# u'sliced\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nbeat'
# u'eggs,'
# u'vanilla,'
# u'cinnamon,'
# u'and'
# u'sugar'
# u'together'
# u'in'
# u'a'
# u'bowl.'
# u'place'
# u'bread'
# u'into'
# u'the'
# u'egg'
# u'mixture'
# u'to'
# u'soak.\nheat'
# u'a'
# u'lightly'
# u'oiled'
# u'skillet'
# u'over'
# u'medium'
# u'heat'
# u'and'
# u'brown'
# u'the'
# u'slices'
# u'of'
# u'bread'
# u'on'
# u'both'
# u'sides.'
# u'heat'
# u'a'
# u'smaller'
# u'lightly'
# u'oiled'
# u'skillet'
# u'over'
# u'medium-low'
# u'heat'
# u'and'
# u'pour'
# u'the'
# u'remaining'
# u'egg'
# u'mixture'
# u'into'
# u'the'
# u'skillet.'
# u'allow'
# u'the'
# u'eggs'
# u'to'
# u'set'
# u'in'
# u'the'
# u'skillet'
# u'for'
# u'1'
# u'to'
# u'2'
# u'minutes,'
# u'then'
# u'continue'
# u'to'
# u'cook'
# u'and'
# u'stir'
# u'eggs'
# u'until'
# u'scrambled.\nplace'
# u'1'
# u'slice'
# u'of'
# u'toast'
# u'onto'
# u'a'
# u'plate'
# u'and'
# u'top'
# u'with'
# u'the'
# u'eggs.'
# u'layer'
# u'the'
# u'slices'
# u'of'
# u'banana'
# u'over'
# u'the'
# u'eggs,'
# u'then'
# u'place'
# u'the'
# u'second'
# u'slice'
# u'of'
# u'toast'
# u'on'
# u'top'
# u'to'
# u'make'
# u'a'
# u'sandwich.\n'
# u'1/2'
# u'cup'
# u'mexican-style'
# u'hot'
# u'sauce'
# u'(such'
# u'as'
# u'valentina)\n1'
# u'tablespoon'
# u'paprika\n1'
# u'tablespoon'
# u'cayenne'
# u'pepper\n1'
# u'tablespoon'
# u'brown'
# u'sugar,'
# u'or'
# u'more'
# u'to'
# u'taste\n4'
# u'chicken'
# u'thighs\npreheat'
# u'oven'
# u'to'
# u'400'
# u'degrees'
# u'f'
# u'(200'
# u'degrees'
# u'c).'
# u'grease'
# u'a'
# u'small'
# u'baking'
# u'dish.\nmix'
# u'the'
# u'hot'
# u'sauce,'
# u'paprika,'
# u'ground'
# u'cayenne'
# u'pepper,'
# u'and'
# u'brown'
# u'sugar'
# u'in'
# u'a'
# u'bowl,'
# u'and'
# u'stir'
# u'until'
# u'the'
# u'mixture'
# u'is'
# u'well'
# u'combined.'
# u'place'
# u'the'
# u'chicken'
# u'thighs'
# u'in'
# u'the'
# u'baking'
# u'dish,'
# u'and'
# u'coat'
# u'them'
# u'with'
# u'a'
# u'layer'
# u'of'
# u'sauce.'
# u'cover'
# u'the'
# u'dish'
# u'with'
# u'foil.\nbake'
# u'in'
# u'the'
# u'preheated'
# u'oven'
# u'for'
# u'20'
# u'minutes.'
# u'remove'
# u'the'
# u'foil,'
# u'and'
# u'bake'
# u'until'
# u'the'
# u'chicken'
# u'has'
# u'cooked'
# u'through,'
# u'and'
# u'the'
# u'sauce'
# u'has'
# u'thickened'
# u'and'
# u'started'
# u'to'
# u'brown,'
# u'about'
# u'20'
# u'more'
# u'minutes.\n'
# u'2'
# u'tablespoons'
# u'butter\n2'
# u'tablespoons'
# u'minced'
# u'garlic\n1'
# u'large'
# u'lemon,'
# u'juiced\n1/2'
# u'teaspoon'
# u'dried'
# u'tarragon\n4'
# u'boneless,'
# u'skinless'
# u'chicken'
# u'breasts\n20'
# u'pitted'
# u'green'
# u'olives\npreheat'
# u'an'
# u'oven'
# u'to'
# u'350'
# u'degrees'
# u'f'
# u'(175'
# u'degrees'
# u'c).\nmelt'
# u'the'
# u'butter'
# u'in'
# u'an'
# u'oven-safe'
# u'pan'
# u'over'
# u'medium'
# u'heat.'
# u'stir'
# u'the'
# u'garlic,'
# u'lemon'
# u'juice,'
# u'and'
# u'tarragon'
# u'into'
# u'the'
# u'butter.'
# u'cook'
# u'the'
# u'chicken'
# u'breasts'
# u'in'
# u'the'
# u'butter'
# u'mixture'
# u'until'
# u'evenly'
# u'browned,'
# u'3'
# u'to'
# u'5'
# u'minutes'
# u'per'
# u'side.'
# u'add'
# u'the'
# u'olives'
# u'to'
# u'the'
# u'pan.\ntransfer'
# u'the'
# u'pan'
# u'to'
# u'the'
# u'preheated'
# u'oven'
# u'and'
# u'bake'
# u'until'
# u'the'
# u'chicken'
# u'is'
# u'no'
# u'longer'
# u'pink'
# u'in'
# u'the'
# u'center'
# u'and'
# u'the'
# u'juices'
# u'run'
# u'clear,'
# u'about'
# u'20'
# u'minutes.'
# u'an'
# u'instant-read'
# u'thermometer'
# u'inserted'
# u'into'
# u'the'
# u'center'
# u'should'
# u'read'
# u'at'
# u'least'
# u'165'
# u'degrees'
# u'f'
# u'(74'
# u'degrees'
# u'c).\n'
# u'1/2'
# u'pound'
# u'ground'
# u'turkey\n1/2'
# u'pound'
# u'ground'
# u'chicken'
# u'breast\n1/2'
# u'pound'
# u'bulk'
# u'pork'
# u'sausage\n1'
# u'egg,'
# u'beaten\n1'
# u'(4'
# u'ounce)'
# u'packet'
# u'crushed'
# u'saltine'
# u'crackers\n1/2'
# u'cup'
# u'sweet'
# u'barbeque'
# u'sauce\n1'
# u'tablespoon'
# u'prepared'
# u'yellow'
# u'mustard\n1'
# u'teaspoon'
# u'hickory-flavored'
# u'liquid'
# u'smoke\n2'
# u'teaspoons'
# u'dried'
# u'parsley\n1'
# u'teaspoon'
# u'dried'
# u'minced'
# u'onion\n1'
# u'teaspoon'
# u'onion'
# u'powder\n1'
# u'teaspoon'
# u'garlic'
# u'salt\n1'
# u'teaspoon'
# u'seasoned'
# u'salt\nglaze:\n1'
# u'tablespoon'
# u'brown'
# u'sugar\n2'
# u'tablespoons'
# u'sweet'
# u'barbeque'
# u'sauce\n1'
# u'tablespoon'
# u'prepared'
# u'yellow'
# u'mustard\npreheat'
# u'oven'
# u'to'
# u'350'
# u'degrees'
# u'f'
# u'(175'
# u'degrees'
# u'c).'
# u'grease'
# u'a'
# u'9x9'
# u'inch'
# u'baking'
# u'pan.\ncombine'
# u'the'
# u'turkey,'
# u'chicken,'
# u'sausage,'
# u'and'
# u'egg'
# u'in'
# u'a'
# u'large'
# u'bowl.'
# u'stir'
# u'in'
# u'the'
# u'saltine'
# u'crackers,'
# u'1/2'
# u'cup'
# u'barbeque'
# u'sauce,'
# u'1'
# u'tablespoon'
# u'of'
# u'mustard,'
# u'liquid'
# u'smoke,'
# u'parsley,'
# u'dried'
# u'onion,'
# u'onion'
# u'powder,'
# u'garlic'
# u'salt,'
# u'and'
# u'seasoned'
# u'salt;'
# u'mix'
# u'well.'
# u'press'
# u'into'
# u'the'
# u'prepared'
# u'pan.\nbake'
# u'meatloaf'
# u'in'
# u'preheated'
# u'oven'
# u'for'
# u'25'
# u'minutes.'
# u'combine'
# u'the'
# u'brown'
# u'sugar'
# u'with'
# u'the'
# u'remaining'
# u'2'
# u'tablespoons'
# u'of'
# u'barbeque'
# u'sauce,'
# u'and'
# u'1'
# u'tablespoon'
# u'of'
# u'mustard'
# u'to'
# u'make'
# u'a'
# u'glaze.'
# u'remove'
# u'meatloaf'
# u'from'
# u'oven;'
# u'brush'
# u'with'
# u'glaze.'
# u'return'
# u'the'
# u'meatloaf'
# u'to'
# u'the'
# u'oven,'
# u'and'
# u'bake'
# u'until'
# u'no'
# u'longer'
# u'pink'
# u'in'
# u'the'
# u'center,'
# u'about'
# u'25'
# u'additional'
# u'minutes.'
# u'an'
# u'instant-read'
# u'thermometer'
# u'inserted'
# u'into'
# u'the'
# u'center'
# u'should'
# u'read'
# u'at'
# u'least'
# u'165'
# u'degrees'
# u'f'
# u'(75'
# u'degrees'
# u'c).\n'
# u'2'
# u'teaspoons'
# u'olive'
# u'oil\n2'
# u'skinless,'
# u'boneless'
# u'chicken'
# u'breast'
# u'halves'
# u'-'
# u'cut'
# u'into'
# u'small'
# u'chunks\nflour'
# u'for'
# u'dusting\n1'
# u'(13.4'
# u'ounce)'
# u'package'
# u'room-temperature'
# u'fresh'
# u'pizza'
# u'dough\n1'
# u'cup'
# u'tomato'
# u'sauce\n1'
# u'tablespoon'
# u'olive'
# u'oil\n5'
# u'cloves'
# u'garlic,'
# u'minced\n1'
# u'1/2'
# u'tablespoons'
# u'italian'
# u'seasoning\nsalt'
# u'and'
# u'ground'
# u'black'
# u'pepper'
# u'to'
# u'taste\n1/2'
# u'link'
# u'portuguese'
# u'hot'
# u'chourico'
# u'sausage'
# u'-'
# u'halved'
# u'lengthwise'
# u'and'
# u'sliced'
# u'into'
# u'thin'
# u'half'
# u'moons\n1/4'
# u'red'
# u'onion,'
# u'sliced'
# u'thin\n1/4'
# u'cup'
# u'banana'
# u'pepper'
# u'rings\n1'
# u'(8'
# u'ounce)'
# u'package'
# u'shredded'
# u'mozzarella'
# u'&'
# u'cheddar'
# u'pizza'
# u'cheese\n2'
# u'tablespoons'
# u'grated'
# u'parmesan'
# u'cheese\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\npreheat'
# u'an'
# u'oven'
# u'to'
# u'425'
# u'degrees'
# u'f'
# u'(220'
# u'degrees'
# u'c).'
# u'prepare'
# u'a'
# u'pizza'
# u'pan'
# u'with'
# u'olive'
# u'oil'
# u'and'
# u'flour.\nheat'
# u'2'
# u'teaspoons'
# u'olive'
# u'oil'
# u'in'
# u'a'
# u'skillet'
# u'over'
# u'medium'
# u'heat;'
# u'cook'
# u'the'
# u'chicken'
# u'in'
# u'the'
# u'hot'
# u'oil'
# u'until'
# u'no'
# u'longer'
# u'pink'
# u'in'
# u'the'
# u'center'
# u'and'
# u'the'
# u'juices'
# u'run'
# u'clear,'
# u'5'
# u'to'
# u'10'
# u'minutes.'
# u'set'
# u'aside.\ndust'
# u'a'
# u'flat'
# u'working'
# u'surface'
# u'with'
# u'flour.'
# u'roll'
# u'the'
# u'pizza'
# u'dough'
# u'out'
# u'to'
# u'the'
# u'size'
# u'of'
# u'your'
# u'pizza'
# u'pan.'
# u'place'
# u'dough'
# u'on'
# u'the'
# u'prepared'
# u'pan.\nstir'
# u'the'
# u'tomato'
# u'sauce,'
# u'1'
# u'tablespoon'
# u'olive'
# u'oil,'
# u'garlic,'
# u'italian'
# u'seasoning,'
# u'salt,'
# u'and'
# u'pepper'
# u'together'
# u'in'
# u'a'
# u'small'
# u'bowl;'
# u'spread'
# u'evenly'
# u'over'
# u'the'
# u'surface'
# u'of'
# u'the'
# u'dough.'
# u'scatter,'
# u'in'
# u'order,'
# u'the'
# u'chicken,'
# u'chourico,'
# u'red'
# u'onion,'
# u'banana'
# u'peppers,'
# u'pizza'
# u'cheese,'
# u'and'
# u'parmesan'
# u'over'
# u'the'
# u'tomato'
# u'sauce'
# u'mixture.\nbake'
# u'in'
# u'the'
# u'preheated'
# u'oven'
# u'on'
# u'the'
# u'middle'
# u'rack'
# u'until'
# u'the'
# u'cheese'
# u'is'
# u'lightly'
# u'browned,'
# u'about'
# u'20'
# u'minutes.'
# u'switch'
# u'the'
# u'oven'
# u'setting'
# u'to'
# u'broil'
# u'and'
# u'cook'
# u'another'
# u'5'
# u'minutes.\n'
# u'2'
# u'skinless,'
# u'boneless'
# u'chicken'
# u'breast'
# u'halves\n2'
# u'tablespoons'
# u'balsamic'
# u'vinegar\n3'
# u'1/2'
# u'cups'
# u'water\n1'
# u'1/2'
# u'cups'
# u'vegetable'
# u'stock\n1'
# u'tablespoon'
# u'olive'
# u'oil\n1'
# u'large'
# u'chopped'
# u'onion\n1'
# u'clove'
# u'garlic,'
# u'minced\nsalt'
# u'and'
# u'pepper'
# u'to'
# u'taste\n1'
# u'1/2'
# u'cups'
# u'sliced'
# u'fresh'
# u'mushrooms\n1'
# u'cup'
# u'1%'
# u'milk\n1/4'
# u'cup'
# u'fat-free'
# u'evaporated'
# u'milk\n1'
# u'cup'
# u'pearl'
# u'barley\n1'
# u'teaspoon'
# u'butter\n1/2'
# u'cup'
# u'grated'
# u'parmesan'
# u'cheese\n1/2'
# u'cup'
# u'grated'
# u'romano'
# u'cheese\npreheat'
# u'an'
# u'oven'
# u'to'
# u'350'
# u'degrees'
# u'f'
# u'(175'
# u'degrees'
# u'c).'
# u'place'
# u'chicken'
# u'breasts'
# u'in'
# u'a'
# u'baking'
# u'dish'
# u'and'
# u'coat'
# u'with'
# u'balsamic'
# u'vinegar.\nbake'
# u'the'
# u'chicken'
# u'breasts'
# u'in'
# u'the'
# u'preheated'
# u'until'
# u'no'
# u'longer'
# u'pink'
# u'in'
# u'the'
# u'center'
# u'and'
# u'the'
# u'juices'
# u'run'
# u'clear,'
# u'about'
# u'45'
# u'minutes.'
# u'an'
# u'instant-read'
# u'thermometer'
# u'inserted'
# u'into'
# u'the'
# u'center'
# u'should'
# u'read'
# u'at'
# u'least'
# u'165'
# u'degrees'
# u'f'
# u'(74'
# u'degrees'
# u'c).'
# u'slice'
# u'chicken'
# u'into'
# u'small'
# u'pieces.'
# u'set'
# u'aside.\nin'
# u'the'
# u'meantime,'
# u'bring'
# u'the'
# u'water'
# u'and'
# u'vegetable'
# u'stock'
# u'to'
# u'a'
# u'low'
# u'boil'
# u'in'
# u'a'
# u'saucepan,'
# u'then'
# u'turn'
# u'off'
# u'the'
# u'heat.'
# u'heat'
# u'the'
# u'olive'
# u'oil'
# u'in'
# u'a'
# u'large,'
# u'heavy-bottomed'
# u'saucepan'
# u'over'
# u'medium-high'
# u'heat.'
# u'add'
# u'the'
# u'onion'
# u'and'
# u'garlic;'
# u'cook'
# u'and'
# u'stir'
# u'until'
# u'the'
# u'onion'
# u'begins'
# u'to'
# u'turn'
# u'golden'
# u'brown'
# u'at'
# u'the'
# u'edges,'
# u'about'
# u'2'
# u'minutes.'
# u'season'
# u'with'
# u'salt'
# u'and'
# u'pepper,'
# u'then'
# u'add'
# u'mushrooms,'
# u'cooking'
# u'until'
# u'mushrooms'
# u'are'
# u'tender.'
# u'pour'
# u'the'
# u'1%'
# u'milk'
# u'and'
# u'the'
# u'evaporated'
# u'milk'
# u'into'
# u'the'
# u'same'
# u'saucepan'
# u'and'
# u'heat'
# u'for'
# u'2'
# u'minutes.'
# u'stir'
# u'in'
# u'the'
# u'barley.'
# u'reduce'
# u'the'
# u'heat'
# u'to'
# u'medium'
# u'and'
# u'stir'
# u'in'
# u'1'
# u'cup'
# u'of'
# u'the'
# u'boiling'
# u'vegetable'
# u'broth;'
# u'continue'
# u'stirring'
# u'until'
# u'the'
# u'barley'
# u'has'
# u'absorbed'
# u'the'
# u'liquid'
# u'and'
# u'turned'
# u'creamy.'
# u'repeat'
# u'this'
# u'process'
# u'until'
# u'there'
# u'is'
# u'only'
# u'1'
# u'cup'
# u'of'
# u'broth'
# u'left.'
# u'stir'
# u'in'
# u'the'
# u'chicken'
# u'with'
# u'the'
# u'last'
# u'cup'
# u'of'
# u'broth.'
# u'when'
# u'finished,'
# u'the'
# u'barley'
# u'should'
# u'be'
# u'tender,'
# u'yet'
# u'slightly'
# u'firm,'
# u'about'
# u'45'
# u'minutes.'
# u'stir'
# u'in'
# u'the'
# u'butter,'
# u'parmesan'
# u'cheese,'
# u'and'
# u'romano'
# u'cheese'
# u'before'
# u'serving.\n'
# u'1'
# u'cup'
# u'sour'
# u'cream\n2'
# u'tablespoons'
# u'dijon'
# u'mustard\n2'
# u'cloves'
# u'garlic,'
# u'minced\n1/2'
# u'teaspoon'
# u'black'
# u'pepper\n4'
# u'skinless,'
# u'boneless'
# u'chicken'
# u'breast'
# u'halves\n1'
# u'cup'
# u'crushed'
# u'cornflakes'
# u'cereal\n1'
# u'(1'
# u'ounce)'
# u'package'
# u'dry'
# u'onion'
# u'soup'
# u'mix\n3'
# u'tablespoons'
# u'butter,'
# u'melted\npreheat'
# u'an'
# u'oven'
# u'to'
# u'400'
# u'degrees'
# u'f'
# u'(200'
# u'degrees'
# u'c).'
# u'butter'
# u'a'
# u'baking'
# u'dish.\nwhisk'
# u'the'
# u'sour'
# u'cream,'
# u'dijon'
# u'mustard,'
# u'garlic,'
# u'and'
# u'pepper'
# u'together'
# u'in'
# u'a'
# u'large'
# u'bowl.'
# u'add'
# u'the'
# u'chicken'
# u'and'
# u'turn'
# u'to'
# u'assure'
# u'the'
# u'breasts'
# u'are'
# u'well'
# u'coated.'
# u'refrigerate'
# u'20'
# u'to'
# u'30'
# u'minutes.\ncombine'
# u'the'
# u'cornflakes'
# u'and'
# u'onion'
# u'soup'
# u'mix'
# u'in'
# u'a'
# u'bowl.'
# u'gently'
# u'press'
# u'the'
# u'chicken'
# u'breasts'
# u'into'
# u'the'
# u'cornflakes'
# u'mixture'
# u'to'
# u'coat'
# u'and'
# u'shake'
# u'off'
# u'any'
# u'excess.'
# u'lie'
# u'the'
# u'coated'
# u'breasts'
# u'in'
# u'the'
# u'buttered'
# u'baking'
# u'dish.'
# u'drizzle'
# u'the'
# u'melted'
# u'butter'
# u'over'
# u'the'
# u'chicken.\nbake'
# u'in'
# u'the'
# u'preheated'
# u'oven'
# u'until'
# u'the'
# u'chicken'
# u'is'
# u'golden'
# u'brown,'
# u'20'
# u'to'
# u'25'
# u'minutes.'
# u'an'
# u'instant-read'
# u'thermometer'
# u'inserted'
# u'into'
# u'the'
# u'center'
# u'should'
# u'read'
# u'at'
# u'least'
# u'165'
# u'degrees'
# u'f'
# u'(74'
# u'degrees'
# u'c).\n'
# u'2'
# u'pounds'
# u'pork'
# u'tenderloin\n1/4'
# u'cup'
# u'softened'
# u'butter\nsalt'
# u'and'
# u'pepper'
# u'to'
# u'taste\n1'
# u'teaspoon'
# u'ground'
# u'thyme\n2'
# u'teaspoons'
# u'garlic'
# u'powder\n1'
# u'(18'
# u'ounce)'
# u'jar'
# u'apricot'
# u'preserves\n2'
# u'tablespoons'
# u'honey,'
# u'or'
# u'to'
# u'taste\n1/4'
# u'cup'
# u'dry'
# u'sherry\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\npreheat'
# u'an'
# u'oven'
# u'to'
# u'350'
# u'degrees'
# u'f'
# u'(175'
# u'degrees'
# u'c).\nspread'
# u'butter'
# u'all'
# u'over'
# u'the'
# u'pork'
# u'tenderloin.'
# u'season'
# u'with'
# u'salt,'
# u'pepper,'
# u'and'
# u'thyme.'
# u'combine'
# u'garlic'
# u'powder,'
# u'apricot'
# u'preserves,'
# u'honey,'
# u'and'
# u'sherry'
# u'in'
# u'a'
# u'separate'
# u'bowl.\nroast'
# u'the'
# u'pork'
# u'in'
# u'the'
# u'preheated'
# u'oven'
# u'for'
# u'30'
# u'to'
# u'40'
# u'minutes.'
# u'remove'
# u'the'
# u'pork'
# u'from'
# u'the'
# u'oven'
# u'and'
# u'brush'
# u'with'
# u'the'
# u'apricot'
# u'sauce.'
# u'return'
# u'the'
# u'pork'
# u'to'
# u'the'
# u'oven.'
# u'continue'
# u'roasting,'
# u'basting'
# u'occasionally'
# u'with'
# u'the'
# u'remaining'
# u'sauce,'
# u'until'
# u'the'
# u'pork'
# u'is'
# u'no'
# u'longer'
# u'pink'
# u'in'
# u'the'
# u'center,'
# u'about'
# u'15'
# u'minutes.'
# u'an'
# u'instant-read'
# u'thermometer'
# u'inserted'
# u'into'
# u'the'
# u'center'
# u'should'
# u'read'
# u'145'
# u'degrees'
# u'f'
# u'(63'
# u'degrees'
# u'c).\n'
# u'1'
# u'(15'
# u'ounce)'
# u'can'
# u'garbanzo'
# u'beans,'
# u'drained\n1/2'
# u'cup'
# u'crumbled'
# u'feta'
# u'cheese\n1'
# u'(4'
# u'ounce)'
# u'jar'
# u'roasted'
# u'red'
# u'bell'
# u'peppers,'
# u'drained\n3'
# u'tablespoons'
# u'lemon'
# u'juice\n1'
# u'tablespoon'
# u'chopped'
# u'fresh'
# u'parsley\n1/2'
# u'teaspoon'
# u'cayenne'
# u'pepper\n1/4'
# u'teaspoon'
# u'salt\nplace'
# u'the'
# u'garbanzo'
# u'beans,'
# u'feta'
# u'cheese,'
# u'drained'
# u'red'
# u'peppers,'
# u'lemon'
# u'juice,'
# u'parsley,'
# u'cayenne'
# u'pepper,'
# u'and'
# u'salt'
# u'in'
# u'the'
# u'bowl'
# u'of'
# u'a'
# u'food'
# u'processor;'
# u'blend'
# u'until'
# u'smooth.\n'
# u'2'
# u'tablespoons'
# u'olive'
# u'oil\n2'
# u'tablespoons'
# u'butter\n4'
# u'skinless'
# u'boneless'
# u'chicken'
# u'breasts,'
# u'cut'
# u'into'
# u'2-inch'
# u'cubes\n2'
# u'tablespoons'
# u'worcestershire'
# u'sauce\n1'
# u'teaspoon'
# u'garlic'
# u'salt\nblack'
# u'pepper'
# u'to'
# u'taste\n2'
# u'cloves'
# u'garlic,'
# u'minced\n1/2'
# u'pound'
# u'chorizo'
# u'sausage,'
# u'casings'
# u'removed\n4'
# u'cups'
# u'chicken'
# u'stock\n1'
# u'(14.5'
# u'ounce)'
# u'can'
# u'mexican-style'
# u'stewed'
# u'tomatoes\n1'
# u'cup'
# u'heavy'
# u'cream\nsalt'
# u'to'
# u'taste\n1'
# u'cup'
# u'shredded'
# u'monterey'
# u'jack'
# u'cheese\n1/4'
# u'cup'
# u'grated'
# u'parmesan'
# u'cheese\n1/4'
# u'cup'
# u'sour'
# u'cream,'
# u'for'
# u'topping\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nheat'
# u'the'
# u'olive'
# u'oil'
# u'in'
# u'a'
# u'large'
# u'pot'
# u'over'
# u'high'
# u'heat,'
# u'then'
# u'add'
# u'the'
# u'butter.'
# u'stir'
# u'in'
# u'chicken'
# u'and'
# u'season'
# u'with'
# u'worcestershire'
# u'sauce,'
# u'garlic'
# u'salt,'
# u'and'
# u'pepper.'
# u'cook'
# u'the'
# u'chicken'
# u'breasts'
# u'until'
# u'no'
# u'longer'
# u'pink'
# u'in'
# u'the'
# u'center,'
# u'then'
# u'stir'
# u'in'
# u'the'
# u'garlic.'
# u'place'
# u'chicken'
# u'onto'
# u'a'
# u'plate'
# u'and'
# u'set'
# u'aside.\ncook'
# u'the'
# u'chorizo'
# u'until'
# u'it'
# u'becomes'
# u'a'
# u'dark'
# u'golden'
# u'brown,'
# u'breaking'
# u'up'
# u'the'
# u'large'
# u'pieces,'
# u'using'
# u'the'
# u'same'
# u'pot'
# u'over'
# u'medium-high'
# u'heat.'
# u'stir'
# u'in'
# u'the'
# u'chicken'
# u'stock,'
# u'tomatoes,'
# u'and'
# u'reserved'
# u'chicken'
# u'with'
# u'juices.'
# u'reduce'
# u'heat'
# u'to'
# u'medium-low'
# u'and'
# u'simmer'
# u'for'
# u'20'
# u'minutes.'
# u'stir'
# u'in'
# u'heavy'
# u'cream'
# u'and'
# u'simmer'
# u'for'
# u'another'
# u'5'
# u'minutes.'
# u'season'
# u'with'
# u'salt.'
# u'serve'
# u'soup'
# u'garnished'
# u'with'
# u'monterey'
# u'jack'
# u'cheese,'
# u'parmesan'
# u'cheese,'
# u'and'
# u'a'
# u'dollop'
# u'of'
# u'sour'
# u'cream.\n'
# u'1'
# u'(6'
# u'ounce)'
# u'can'
# u'albacore'
# u'tuna'
# u'in'
# u'water,'
# u'drained'
# u'and'
# u'flaked\n2'
# u'tablespoons'
# u'mayonnaise\n1/4'
# u'teaspoon'
# u'dried'
# u'minced'
# u'onion\n1/4'
# u'teaspoon'
# u'onion'
# u'powder\n1'
# u'1/2'
# u'teaspoons'
# u'sweet'
# u'pickle'
# u'relish\n2'
# u'(1'
# u'ounce)'
# u'slices'
# u'swiss'
# u'cheese,'
# u'diced\nsalt'
# u'and'
# u'pepper'
# u'to'
# u'taste\n1'
# u'(8'
# u'ounce)'
# u'package'
# u'fresh'
# u'white'
# u'mushrooms,'
# u'cleaned'
# u'and'
# u'stems'
# u'removed\npreheat'
# u'an'
# u'oven'
# u'to'
# u'350'
# u'degrees'
# u'f'
# u'(175'
# u'degrees'
# u'c).\ncombine'
# u'the'
# u'tuna,'
# u'mayonnaise,'
# u'dried'
# u'onion,'
# u'onion'
# u'powder,'
# u'sweet'
# u'relish,'
# u'swiss'
# u'cheese,'
# u'salt,'
# u'and'
# u'pepper'
# u'in'
# u'a'
# u'large'
# u'bowl.'
# u'fill'
# u'mushroom'
# u'caps'
# u'with'
# u'the'
# u'tuna'
# u'mixture;'
# u'place'
# u'on'
# u'baking'
# u'sheet.\nbake'
# u'in'
# u'preheated'
# u'oven'
# u'until'
# u'the'
# u'mushrooms'
# u'are'
# u'soft,'
# u'and'
# u'begin'
# u'to'
# u'give'
# u'up'
# u'their'
# u'juices,'
# u'20'
# u'to'
# u'25'
# u'minutes.\n'
# u'2'
# u'cups'
# u'water\n2'
# u'ounces'
# u'mai'
# u'fun'
# u'(angel'
# u'hair)'
# u'rice'
# u'noodles\n1'
# u'teaspoon'
# u'vegetable'
# u'oil\n4'
# u'shiitake'
# u'mushrooms,'
# u'sliced\n2'
# u'teaspoons'
# u'vegetable'
# u'oil\n1'
# u'(16'
# u'ounce)'
# u'package'
# u'ground'
# u'turkey\n6'
# u'green'
# u'onions,'
# u'chopped\n1/4'
# u'cup'
# u'chopped'
# u'water'
# u'chestnuts\n4'
# u'teaspoons'
# u'finely'
# u'minced'
# u'fresh'
# u'ginger'
# u'root\n2'
# u'teaspoons'
# u'minced'
# u'garlic\n3'
# u'tablespoons'
# u'soy'
# u'sauce\n2'
# u'tablespoons'
# u'brown'
# u'sugar\n1'
# u'tablespoon'
# u'rice'
# u'vinegar\n1'
# u'teaspoon'
# u'sesame'
# u'oil\n1'
# u'teaspoon'
# u'finely'
# u'grated'
# u'orange'
# u'zest\n12'
# u'leaves'
# u'green'
# u'leaf'
# u'lettuce\ntoppings\n1/2'
# u'cup'
# u'bean'
# u'sprouts\n1'
# u'carrot,'
# u'grated\n1/2'
# u'cup'
# u'salted'
# u'peanuts\n1/2'
# u'cup'
# u'chopped'
# u'fresh'
# u'cilantro\n1/2'
# u'cup'
# u'sweet'
# u'chili'
# u'sauce\nbring'
# u'2'
# u'cups'
# u'of'
# u'water'
# u'to'
# u'a'
# u'boil'
# u'in'
# u'a'
# u'small'
# u'saucepan.'
# u'turn'
# u'off'
# u'heat;'
# u'stir'
# u'in'
# u'rice'
# u'noodles.'
# u'cover,'
# u'and'
# u'allow'
# u'noodles'
# u'to'
# u'soak'
# u'until'
# u'soft,'
# u'5'
# u'to'
# u'7'
# u'minutes.'
# u'rinse'
# u'with'
# u'cold'
# u'water.'
# u'drain'
# u'well.\nheat'
# u'1'
# u'teaspoon'
# u'of'
# u'the'
# u'oil'
# u'in'
# u'a'
# u'large'
# u'skillet'
# u'over'
# u'medium-high'
# u'heat.'
# u'cook'
# u'the'
# u'mushrooms'
# u'in'
# u'the'
# u'hot'
# u'oil'
# u'until'
# u'they'
# u'are'
# u'browned'
# u'and'
# u'softened,'
# u'about'
# u'2'
# u'minutes.'
# u'remove'
# u'the'
# u'mushrooms'
# u'from'
# u'the'
# u'pan.'
# u'reserve.\nheat'
# u'the'
# u'remaining'
# u'2'
# u'teaspoons'
# u'of'
# u'oil'
# u'in'
# u'the'
# u'pan.'
# u'cook'
# u'and'
# u'stir'
# u'the'
# u'turkey'
# u'in'
# u'the'
# u'oil'
# u'until'
# u'it'
# u'is'
# u'no'
# u'longer'
# u'pink,'
# u'5'
# u'to'
# u'7'
# u'minutes.'
# u'stir'
# u'in'
# u'the'
# u'green'
# u'onions,'
# u'water'
# u'chestnuts,'
# u'ginger,'
# u'and'
# u'garlic;'
# u'continue'
# u'to'
# u'cook'
# u'for'
# u'1'
# u'minute.'
# u'mix'
# u'in'
# u'the'
# u'reserved'
# u'mushrooms,'
# u'soy'
# u'sauce,'
# u'and'
# u'brown'
# u'sugar.'
# u'simmer'
# u'briefly'
# u'to'
# u'combine'
# u'the'
# u'flavors.'
# u'take'
# u'the'
# u'pan'
# u'off'
# u'the'
# u'heat;'
# u'stir'
# u'in'
# u'the'
# u'rice'
# u'vinegar,'
# u'sesame'
# u'oil,'
# u'and'
# u'orange'
# u'zest.\nto'
# u'assemble'
# u'lettuce'
# u'wraps,'
# u'place'
# u'a'
# u'bit'
# u'of'
# u'turkey'
# u'filling'
# u'on'
# u'each'
# u'lettuce'
# u'leaf.'
# u'top'
# u'each'
# u'with'
# u'cooked'
# u'noodles,'
# u'and'
# u'a'
# u'sprinkle'
# u'of'
# u'bean'
# u'sprouts,'
# u'carrots,'
# u'peanuts,'
# u'and'
# u'cilantro.'
# u'serve'
# u'with'
# u'sweet'
# u'chili'
# u'sauce'
# u'for'
# u'dipping.\n'
# u'cooking'
# u'spray\n1'
# u'small'
# u'tomato,'
# u'chopped\ngarlic'
# u'salt'
# u'to'
# u'taste\nfreshly'
# u'ground'
# u'black'
# u'pepper'
# u'to'
# u'taste\n1'
# u'egg\n2'
# u'teaspoons'
# u'water\n1'
# u'teaspoon'
# u'grated'
# u'parmesan'
# u'cheese\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nprepare'
# u'a'
# u'skillet'
# u'with'
# u'cooking'
# u'spray'
# u'and'
# u'place'
# u'over'
# u'medium'
# u'heat.'
# u'put'
# u'the'
# u'chopped'
# u'tomato'
# u'in'
# u'the'
# u'hot'
# u'skillet;'
# u'season'
# u'with'
# u'garlic'
# u'salt'
# u'and'
# u'pepper.\nwhisk'
# u'the'
# u'egg,'
# u'water,'
# u'and'
# u'parmesan'
# u'cheese'
# u'together'
# u'in'
# u'a'
# u'small'
# u'bowl;'
# u'add'
# u'to'
# u'the'
# u'skillet.'
# u'reduce'
# u'heat'
# u'to'
# u'medium-low.'
# u'when'
# u'the'
# u'eggs'
# u'have'
# u'begun'
# u'to'
# u'set'
# u'at'
# u'the'
# u'edges,'
# u'use'
# u'spatula'
# u'or'
# u'wooden'
# u'spoon'
# u'to'
# u'scrape'
# u'the'
# u'eggs'
# u'from'
# u'the'
# u'edge'
# u'of'
# u'the'
# u'pan'
# u'to'
# u'the'
# u'center,'
# u'forming'
# u'large'
# u'soft'
# u'curds.'
# u'continue'
# u'scraping'
# u'your'
# u'spoon'
# u'along'
# u'the'
# u'bottom'
# u'of'
# u'the'
# u'pan'
# u'to'
# u'redistribute'
# u'the'
# u'eggs'
# u'as'
# u'they'
# u'cook.\ncook'
# u'until'
# u'the'
# u'eggs'
# u'are'
# u'set'
# u'but'
# u'still'
# u'slightly'
# u'moist,'
# u'about'
# u'5'
# u'minutes.\n'
# u'1'
# u'tablespoon'
# u'butter\n1'
# u'large'
# u'onion,'
# u'chopped\n1'
# u'large'
# u'green'
# u'bell'
# u'pepper,'
# u'sliced'
# u'thin\n1'
# u'teaspoon'
# u'crushed'
# u'garlic\n2'
# u'(14.5'
# u'ounce)'
# u'cans'
# u'diced'
# u'tomatoes,'
# u'drained'
# u'and'
# u'juice'
# u'reserved\n1'
# u'cup'
# u'burgundy'
# u'wine\n1'
# u'1/2'
# u'tablespoons'
# u'italian'
# u'seasoning\n1'
# u'teaspoon'
# u'salt\n1'
# u'teaspoon'
# u'ground'
# u'black'
# u'pepper\n1/2'
# u'teaspoon'
# u'garlic'
# u'salt\n1'
# u'whole'
# u'chicken,'
# u'cut'
# u'into'
# u'pieces\n2'
# u'tablespoons'
# u'all-purpose'
# u'flour\n1'
# u'(16'
# u'ounce)'
# u'package'
# u'spaghetti\nmelt'
# u'the'
# u'butter'
# u'in'
# u'a'
# u'large'
# u'stockpot'
# u'over'
# u'medium'
# u'heat.'
# u'cook'
# u'the'
# u'onion,'
# u'bell'
# u'pepper,'
# u'and'
# u'garlic'
# u'in'
# u'the'
# u'melted'
# u'butter'
# u'until'
# u'they'
# u'begin'
# u'to'
# u'soften,'
# u'about'
# u'3'
# u'minutes.'
# u'add'
# u'the'
# u'tomatoes,'
# u'wine,'
# u'italian'
# u'seasoning,'
# u'salt,'
# u'pepper,'
# u'and'
# u'garlic'
# u'salt;'
# u'cook'
# u'and'
# u'stir'
# u'until'
# u'the'
# u'mixture'
# u'just'
# u'begins'
# u'to'
# u'boil.'
# u'reduce'
# u'the'
# u'heat'
# u'to'
# u'medium'
# u'low;'
# u'add'
# u'the'
# u'chicken'
# u'and'
# u'cook'
# u'until'
# u'the'
# u'meat'
# u'is'
# u'tender'
# u'enough'
# u'to'
# u'fall'
# u'off'
# u'the'
# u'bone,'
# u'about'
# u'1'
# u'1/2'
# u'hours.'
# u'remove'
# u'the'
# u'bones'
# u'and'
# u'skin'
# u'from'
# u'the'
# u'chicken,'
# u'returning'
# u'the'
# u'meat'
# u'to'
# u'the'
# u'pot.\nheat'
# u'3/4'
# u'cup'
# u'of'
# u'the'
# u'reserved'
# u'liquid'
# u'from'
# u'the'
# u'tomatoes'
# u'in'
# u'the'
# u'microwave'
# u'until'
# u'just'
# u'warmed.'
# u'stir'
# u'the'
# u'flour'
# u'into'
# u'the'
# u'tomato'
# u'liquid'
# u'until'
# u'thick.'
# u'add'
# u'to'
# u'the'
# u'stockpot'
# u'and'
# u'stir'
# u'continually'
# u'until'
# u'the'
# u'mixture'
# u'begins'
# u'to'
# u'thicken.'
# u'remove'
# u'from'
# u'heat'
# u'and'
# u'allow'
# u'to'
# u'sit'
# u'for'
# u'about'
# u'15'
# u'minutes.\nwhile'
# u'the'
# u'chicken'
# u'mixture'
# u'rests,'
# u'bring'
# u'a'
# u'large'
# u'pot'
# u'of'
# u'lightly-salted'
# u'water'
# u'to'
# u'a'
# u'boil.'
# u'stir'
# u'the'
# u'spaghetti'
# u'into'
# u'the'
# u'water'
# u'and'
# u'return'
# u'to'
# u'a'
# u'boil.'
# u'cook'
# u'until'
# u'the'
# u'pasta'
# u'is'
# u'slightly'
# u'tender'
# u'but'
# u'still'
# u'firm'
# u'to'
# u'the'
# u'bite,'
# u'about'
# u'12'
# u'minutes.'
# u'drain.'
# u'ladle'
# u'the'
# u'chicken'
# u'mixture'
# u'over'
# u'the'
# u'drained'
# u'spaghetti'
# u'to'
# u'serve.\n'
# u'10'
# u'unpeeled'
# u'red'
# u'potatoes\n5'
# u'hard'
# u'boiled'
# u'eggs,'
# u'roughly'
# u'chopped\n3/4'
# u'cup'
# u'sour'
# u'cream\n3/4'
# u'cup'
# u'mayonnaise\n1'
# u'tablespoon'
# u'apple'
# u'cider'
# u'vinegar,'
# u'or'
# u'to'
# u'taste\n1'
# u'tablespoon'
# u'dijon'
# u'mustard,'
# u'or'
# u'to'
# u'taste\n1/2'
# u'white'
# u'onion,'
# u'finely'
# u'chopped\n1'
# u'stalk'
# u'celery,'
# u'finely'
# u'chopped\n1'
# u'teaspoon'
# u'celery'
# u'salt\nsalt'
# u'and'
# u'black'
# u'pepper'
# u'to'
# u'taste\n1'
# u'tablespoon'
# u'dried'
# u'dill'
# u'weed\nplace'
# u'the'
# u'potatoes'
# u'in'
# u'a'
# u'large'
# u'pot,'
# u'cover'
# u'them'
# u'with'
# u'water,'
# u'and'
# u'bring'
# u'to'
# u'a'
# u'boil'
# u'over'
# u'high'
# u'heat.'
# u'reduce'
# u'the'
# u'heat'
# u'to'
# u'medium-low,'
# u'and'
# u'simmer'
# u'until'
# u'the'
# u'potatoes'
# u'are'
# u'cooked'
# u'through'
# u'but'
# u'still'
# u'firm,'
# u'about'
# u'20'
# u'minutes.'
# u'remove'
# u'from'
# u'the'
# u'water,'
# u'let'
# u'cool,'
# u'and'
# u'cut'
# u'the'
# u'potatoes'
# u'into'
# u'chunks.'
# u'set'
# u'the'
# u'potatoes'
# u'aside.\nin'
# u'a'
# u'bowl,'
# u'stir'
# u'together'
# u'the'
# u'sour'
# u'cream,'
# u'mayonnaise,'
# u'apple'
# u'cider'
# u'vinegar,'
# u'dijon'
# u'mustard,'
# u'onion,'
# u'celery,'
# u'celery'
# u'salt,'
# u'and'
# u'salt'
# u'and'
# u'pepper'
# u'until'
# u'well'
# u'mixed.\nplace'
# u'the'
# u'potatoes'
# u'and'
# u'eggs'
# u'in'
# u'a'
# u'large'
# u'salad'
# u'bowl,'
# u'and'
# u'sprinkle'
# u'with'
# u'dried'
# u'dill.'
# u'pour'
# u'the'
# u'dressing'
# u'over'
# u'the'
# u'potatoes'
# u'and'
# u'eggs,'
# u'and'
# u'mix'
# u'lightly.'
# u'cover'
# u'and'
# u'refrigerate'
# u'the'
# u'salad'
# u'for'
# u'at'
# u'least'
# u'30'
# u'minutes.'
# u'serve'
# u'cold.\n'
# u'1'
# u'1/2'
# u'cups'
# u'milk\n1/2'
# u'cup'
# u'quick'
# u'cooking'
# u'oats\n2'
# u'tablespoons'
# u'white'
# u'sugar\n1/4'
# u'teaspoon'
# u'ground'
# u'cinnamon\n1'
# u'pinch'
# u'ground'
# u'nutmeg\n1'
# u'pinch'
# u'salt\ncombine'
# u'milk,'
# u'oats,'
# u'sugar,'
# u'cinnamon,'
# u'nutmeg,'
# u'and'
# u'salt'
# u'in'
# u'a'
# u'saucepan.'
# u'bring'
# u'to'
# u'a'
# u'boil,'
# u'stirring'
# u'constantly'
# u'for'
# u'2'
# u'minutes.\n'
# u'3'
# u'cups'
# u'self-rising'
# u'flour\n1/2'
# u'teaspoon'
# u'salt\n1'
# u'cup'
# u'unsalted'
# u'butter,'
# u'at'
# u'room'
# u'temperature\n2'
# u'cups'
# u'white'
# u'sugar\n4'
# u'eggs,'
# u'at'
# u'room'
# u'temperature\n1'
# u'teaspoon'
# u'vanilla'
# u'extract\n2'
# u'tablespoons'
# u'lemon'
# u'zest\n1'
# u'cup'
# u'whole'
# u'milk,'
# u'divided\n2'
# u'1/2'
# u'tablespoons'
# u'fresh'
# u'lemon'
# u'juice,'
# u'divided\nlemon'
# u'cream'
# u'icing\n2'
# u'cups'
# u'chilled'
# u'heavy'
# u'cream\n3/4'
# u'cup'
# u"confectioners'"
# u'sugar\n1'
# u'1/2'
# u'tablespoons'
# u'fresh'
# u'lemon'
# u'juice\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\npreheat'
# u'oven'
# u'to'
# u'375'
# u'degrees'
# u'f'
# u'(190'
# u'degrees'
# u'c).'
# u'line'
# u'30'
# u'cupcake'
# u'pan'
# u'cups'
# u'with'
# u'paper'
# u'liners.\nsift'
# u'the'
# u'self-rising'
# u'flour'
# u'and'
# u'salt'
# u'together'
# u'in'
# u'a'
# u'bowl.'
# u'in'
# u'another'
# u'bowl,'
# u'beat'
# u'the'
# u'unsalted'
# u'butter'
# u'and'
# u'sugar'
# u'with'
# u'an'
# u'electric'
# u'mixer'
# u'until'
# u'light'
# u'and'
# u'fluffy.'
# u'beat'
# u'in'
# u'the'
# u'eggs'
# u'one'
# u'at'
# u'a'
# u'time,'
# u'beating'
# u'each'
# u'egg'
# u'until'
# u'incorporated'
# u'before'
# u'adding'
# u'the'
# u'next.'
# u'mix'
# u'in'
# u'the'
# u'vanilla'
# u'extract'
# u'and'
# u'lemon'
# u'zest.\ngently'
# u'beat'
# u'the'
# u'flour'
# u'mixture'
# u'into'
# u'the'
# u'butter'
# u'mixture,'
# u'one'
# u'third'
# u'at'
# u'a'
# u'time,'
# u'alternating'
# u'with'
# u'half'
# u'the'
# u'milk'
# u'and'
# u'half'
# u'the'
# u'lemon'
# u'juice'
# u'after'
# u'each'
# u'of'
# u'the'
# u'first'
# u'2'
# u'additions'
# u'of'
# u'flour.'
# u'beat'
# u'until'
# u'just'
# u'combined;'
# u'do'
# u'not'
# u'over'
# u'mix.\nfill'
# u'the'
# u'prepared'
# u'cupcake'
# u'liners'
# u'with'
# u'batter'
# u'3/4'
# u'full,'
# u'and'
# u'bake'
# u'in'
# u'the'
# u'preheated'
# u'oven'
# u'until'
# u'a'
# u'toothpick'
# u'inserted'
# u'in'
# u'the'
# u'center'
# u'comes'
# u'out'
# u'clean,'
# u'about'
# u'17'
# u'minutes.'
# u'let'
# u'the'
# u'cupcakes'
# u'cool'
# u'in'
# u'the'
# u'pans'
# u'for'
# u'about'
# u'10'
# u'minutes'
# u'before'
# u'removing'
# u'them'
# u'to'
# u'finish'
# u'cooling'
# u'on'
# u'a'
# u'rack.\nto'
# u'make'
# u'the'
# u'icing,'
# u'beat'
# u'the'
# u'cream'
# u'in'
# u'a'
# u'chilled'
# u'bowl'
# u'with'
# u'an'
# u'electric'
# u'mixer'
# u'set'
# u'on'
# u'low'
# u'until'
# u'the'
# u'cream'
# u'begins'
# u'to'
# u'thicken.'
# u'add'
# u'the'
# u"confectioners'"
# u'sugar'
# u'and'
# u'lemon'
# u'juice,'
# u'a'
# u'little'
# u'at'
# u'a'
# u'time,'
# u'beating'
# u'after'
# u'each'
# u'addition,'
# u'until'
# u'fully'
# u'incorporated.'
# u'increase'
# u'the'
# u'mixer'
# u'speed'
# u'to'
# u'high,'
# u'and'
# u'beat'
# u'until'
# u'the'
# u'icing'
# u'forms'
# u'soft'
# u'peaks,'
# u'about'
# u'5'
# u'minutes.'
# u'spread'
# u'on'
# u'the'
# u'cooled'
# u'cupcakes.'
# u'refrigerate'
# u'leftovers.\n'
# u'sauce:\n1'
# u'1/2'
# u'cups'
# u'soy'
# u'sauce\n3'
# u'tablespoons'
# u'sesame'
# u'oil\n2'
# u'tablespoons'
# u'minced'
# u'garlic\n1'
# u'tablespoon'
# u'minced'
# u'fresh'
# u'ginger'
# u'root\n1'
# u'teaspoon'
# u'ground'
# u'ginger\n1/4'
# u'cup'
# u'brown'
# u'sugar\n2'
# u'1/2'
# u'cups'
# u'water\n1/2'
# u'cup'
# u'rice'
# u'wine\n1/2'
# u'cup'
# u'pear,'
# u'peeled'
# u'and'
# u'grated\n1'
# u'kiwi,'
# u'peeled'
# u'and'
# u'mashed\n2'
# u'teaspoons'
# u'salt\n1'
# u'pinch'
# u'ground'
# u'black'
# u'pepper\nribs:\n4'
# u'pounds'
# u'beef'
# u'short'
# u'ribs\n1'
# u'carrot,'
# u'cut'
# u'into'
# u'large'
# u'dice\n2'
# u'potatoes,'
# u'peeled,'
# u'cut'
# u'into'
# u'large'
# u'chunks\n1/2'
# u'cup'
# u'chopped'
# u'green'
# u'onions\n1'
# u'yellow'
# u'onion,'
# u'cut'
# u'into'
# u'large'
# u'dice\n1'
# u'cup'
# u'chestnuts'
# u'(optional)\n1/2'
# u'cup'
# u'shiitake'
# u'mushrooms,'
# u'sliced'
# u'(optional)\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nto'
# u'make'
# u'the'
# u'sauce,'
# u'combine'
# u'the'
# u'soy'
# u'sauce,'
# u'sesame'
# u'oil,'
# u'garlic,'
# u'fresh'
# u'ginger,'
# u'ground'
# u'ginger,'
# u'brown'
# u'sugar,'
# u'water,'
# u'rice'
# u'wine,'
# u'pear,'
# u'kiwi,'
# u'salt,'
# u'and'
# u'pepper'
# u'in'
# u'a'
# u'large'
# u'bowl.'
# u'whisk'
# u'to'
# u'combine.\nfill'
# u'a'
# u'large'
# u'stockpot'
# u'with'
# u'cold'
# u'water.'
# u'soak'
# u'the'
# u'short'
# u'ribs'
# u'in'
# u'the'
# u'water'
# u'for'
# u'30'
# u'minutes'
# u'to'
# u'1'
# u'hour'
# u'to'
# u'pull'
# u'out'
# u'impurities.'
# u'drain.'
# u'score'
# u'ribs'
# u'by'
# u'slicing'
# u'shallow'
# u'criss'
# u'cross'
# u'cuts'
# u'across'
# u'the'
# u'meat.\nfill'
# u'the'
# u'stockpot'
# u'with'
# u'clean'
# u'water'
# u'and'
# u'bring'
# u'to'
# u'a'
# u'boil.'
# u'simmer'
# u'the'
# u'short'
# u'ribs'
# u'in'
# u'the'
# u'water'
# u'for'
# u'30'
# u'minutes.'
# u'drain.'
# u'return'
# u'the'
# u'simmered'
# u'ribs'
# u'to'
# u'the'
# u'pot;'
# u'pour'
# u'in'
# u'the'
# u'sauce,'
# u'bring'
# u'to'
# u'a'
# u'low'
# u'boil.'
# u'simmer'
# u'the'
# u'ribs'
# u'in'
# u'the'
# u'sauce'
# u'for'
# u'60'
# u'minutes.'
# u'stir'
# u'in'
# u'the'
# u'carrot,'
# u'potatoes,'
# u'green'
# u'onions,'
# u'yellow'
# u'onion,'
# u'chestnuts,'
# u'and'
# u'shiitake'
# u'mushrooms.'
# u'simmer'
# u'until'
# u'vegetables'
# u'are'
# u'tender,'
# u'at'
# u'least'
# u'30'
# u'additional'
# u'minutes.\n'
# u'4'
# u'eggs\n3'
# u'tablespoons'
# u'molasses\n1/2'
# u'cup'
# u'heavy'
# u'cream\n1'
# u'teaspoon'
# u'vanilla'
# u'extract\n1'
# u'pinch'
# u'ground'
# u'ginger\n1'
# u'pinch'
# u'ground'
# u'cinnamon,'
# u'or'
# u'more'
# u'to'
# u'taste\n12'
# u'thick'
# u'slices'
# u'challah'
# u'bread\n1/4'
# u'cup'
# u'butter\nbeat'
# u'together'
# u'the'
# u'eggs,'
# u'molasses,'
# u'cream,'
# u'vanilla,'
# u'ginger,'
# u'and'
# u'cinnamon'
# u'in'
# u'a'
# u'bowl'
# u'until'
# u'smooth.'
# u'dip'
# u'the'
# u'challah'
# u'slices'
# u'in'
# u'the'
# u'batter'
# u'until'
# u'coated'
# u'on'
# u'all'
# u'sides.\nmelt'
# u'half'
# u'of'
# u'the'
# u'butter'
# u'in'
# u'a'
# u'large'
# u'skillet'
# u'over'
# u'medium'
# u'heat.'
# u'place'
# u'half'
# u'of'
# u'the'
# u'challah'
# u'slices'
# u'into'
# u'the'
# u'pan,'
# u'and'
# u'cook'
# u'until'
# u'golden'
# u'brown'
# u'on'
# u'each'
# u'side,'
# u'about'
# u'3'
# u'minutes'
# u'per'
# u'side.'
# u'repeat'
# u'with'
# u'remaining'
# u'butter'
# u'and'
# u'challah'
# u'slices.\n'
# u'4'
# u'ripe'
# u'tomatoes,'
# u'diced\n2'
# u'hass'
# u'avocados,'
# u'diced\n1'
# u'clove'
# u'garlic,'
# u'minced\n3'
# u'tablespoons'
# u'chopped'
# u'red'
# u'onion\n6'
# u'sprigs'
# u'cilantro,'
# u'chopped\n2'
# u'tablespoons'
# u'fresh'
# u'lime'
# u'juice\nsalt'
# u'and'
# u'ground'
# u'black'
# u'pepper'
# u'to'
# u'taste\n1'
# u'lime,'
# u'sliced'
# u'into'
# u'thin'
# u'rounds\ncombine'
# u'the'
# u'tomatoes,'
# u'avocados,'
# u'garlic,'
# u'onion,'
# u'and'
# u'cilantro'
# u'in'
# u'a'
# u'large'
# u'bowl.'
# u'sprinkle'
# u'with'
# u'lime'
# u'juice,'
# u'and'
# u'season'
# u'with'
# u'salt'
# u'and'
# u'pepper.'
# u'garnish'
# u'salad'
# u'with'
# u'thin'
# u'lime'
# u'slices.\n'
# u'1'
# u'(3'
# u'pound)'
# u'whole'
# u'chicken\n1/2'
# u'cup'
# u'all-purpose'
# u'flour\n1/2'
# u'cup'
# u'vegetable'
# u'oil\n1'
# u'(10'
# u'ounce)'
# u'package'
# u'frozen'
# u'chopped'
# u'onions\n1'
# u'(10'
# u'ounce)'
# u'package'
# u'frozen'
# u'green'
# u'bell'
# u'peppers\n5'
# u'stalks'
# u'celery,'
# u'finely'
# u'chopped\n1'
# u'tablespoon'
# u'cajun'
# u'seasoning'
# u'(such'
# u'as'
# u'tony'
# u"chachere's),"
# u'or'
# u'to'
# u'taste\n2'
# u'whole'
# u'bay'
# u'leaves\n1'
# u'(28'
# u'ounce)'
# u'can'
# u'diced'
# u'tomatoes\n1'
# u'pound'
# u'fully-cooked'
# u'smoked'
# u'beef'
# u'sausage'
# u'(such'
# u'as'
# u'hillshire'
# u'farm\xae),'
# u'sliced\n1'
# u'(10'
# u'ounce)'
# u'package'
# u'frozen'
# u'sliced'
# u'okra\nsalt'
# u'and'
# u'black'
# u'pepper'
# u'to'
# u'taste\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nfill'
# u'a'
# u'large'
# u'pot'
# u'partially'
# u'with'
# u'lightly'
# u'salted'
# u'water,'
# u'and'
# u'place'
# u'the'
# u'chicken'
# u'in'
# u'the'
# u'pot.'
# u'bring'
# u'to'
# u'a'
# u'boil,'
# u'reduce'
# u'the'
# u'heat'
# u'to'
# u'a'
# u'simmer,'
# u'and'
# u'cook'
# u'the'
# u'chicken'
# u'until'
# u'the'
# u'meat'
# u'is'
# u'no'
# u'longer'
# u'pink'
# u'and'
# u'the'
# u'juices'
# u'run'
# u'clear,'
# u'about'
# u'1'
# u'hour.'
# u'remove'
# u'the'
# u'chicken'
# u'from'
# u'the'
# u'broth,'
# u'and'
# u'crack'
# u'open'
# u'the'
# u'carcass'
# u'to'
# u'allow'
# u'the'
# u'chicken'
# u'to'
# u'cool.'
# u'reserve'
# u'the'
# u'chicken'
# u'broth.'
# u'after'
# u'the'
# u'chicken'
# u'has'
# u'cooled'
# u'enough'
# u'to'
# u'handle,'
# u'pick'
# u'the'
# u'meat'
# u'from'
# u'the'
# u'bones,'
# u'and'
# u'set'
# u'aside.\nwhile'
# u'the'
# u'chicken'
# u'is'
# u'simmering,'
# u'make'
# u'a'
# u'roux'
# u'by'
# u'whisking'
# u'together'
# u'the'
# u'flour'
# u'and'
# u'vegetable'
# u'oil'
# u'in'
# u'a'
# u'large,'
# u'heavy'
# u'saucepan'
# u'over'
# u'medium-low'
# u'heat.'
# u'cook'
# u'and'
# u'stir'
# u'the'
# u'mixture,'
# u'watching'
# u'constantly'
# u'to'
# u'avoid'
# u'burning,'
# u'until'
# u'the'
# u'roux'
# u'is'
# u'a'
# u'rich'
# u'chocolate'
# u'brown'
# u'color,'
# u'20'
# u'to'
# u'30'
# u'minutes.\nas'
# u'soon'
# u'as'
# u'the'
# u'roux'
# u'has'
# u'reached'
# u'the'
# u'desired'
# u'color,'
# u'stir'
# u'in'
# u'the'
# u'onions,'
# u'bell'
# u'peppers,'
# u'celery,'
# u'cajun'
# u'seasoning,'
# u'and'
# u'bay'
# u'leaves,'
# u'and'
# u'simmer,'
# u'stirring'
# u'occasionally,'
# u'until'
# u'the'
# u'vegetables'
# u'are'
# u'tender,'
# u'about'
# u'45'
# u'minutes.'
# u'pour'
# u'in'
# u'the'
# u'reserved'
# u'chicken'
# u'broth,'
# u'diced'
# u'tomatoes,'
# u'and'
# u'beef'
# u'sausage,'
# u'and'
# u'simmer,'
# u'stirring'
# u'occasionally,'
# u'until'
# u'the'
# u'mixture'
# u'has'
# u'thickened,'
# u'about'
# u'1'
# u'hour.\nmix'
# u'in'
# u'the'
# u'reserved'
# u'chicken'
# u'meat'
# u'and'
# u'okra,'
# u'bring'
# u'back'
# u'to'
# u'a'
# u'simmer,'
# u'and'
# u'cook,'
# u'stirring'
# u'occasionally,'
# u'until'
# u'the'
# u'okra'
# u'is'
# u'tender'
# u'and'
# u'the'
# u'flavors'
# u'have'
# u'blended,'
# u'30'
# u'to'
# u'40'
# u'minutes.\n'
# u'1'
# u'clove'
# u'garlic,'
# u'minced\n1'
# u'(8'
# u'ounce)'
# u'package'
# u'cream'
# u'cheese\n1'
# u'(6'
# u'ounce)'
# u'can'
# u'crabmeat,'
# u'drained'
# u'and'
# u'flaked\n2'
# u'green'
# u'onions'
# u'with'
# u'tops,'
# u'thinly'
# u'sliced\n2'
# u'teaspoons'
# u'worcestershire'
# u'sauce\n1/2'
# u'teaspoon'
# u'light'
# u'soy'
# u'sauce\n48'
# u'wonton'
# u'wrappers\npreheat'
# u'an'
# u'oven'
# u'to'
# u'425'
# u'degrees'
# u'f'
# u'(220'
# u'degrees'
# u'c).'
# u'lightly'
# u'spray'
# u'baking'
# u'sheet'
# u'with'
# u'cooking'
# u'spray.\ncombine'
# u'garlic,'
# u'cream'
# u'cheese,'
# u'crab,'
# u'green'
# u'onions,'
# u'worcestershire'
# u'sauce,'
# u'and'
# u'soy'
# u'sauce'
# u'in'
# u'a'
# u'bowl.'
# u'to'
# u'prevent'
# u'wonton'
# u'skins'
# u'from'
# u'drying,'
# u'prepare'
# u'only'
# u'1'
# u'or'
# u'2'
# u'rangoon'
# u'at'
# u'a'
# u'time.'
# u'place'
# u'1'
# u'teaspoon'
# u'of'
# u'filling'
# u'onto'
# u'the'
# u'center'
# u'of'
# u'each'
# u'wonton'
# u'skin.'
# u'moisten'
# u'the'
# u'edges'
# u'with'
# u'water'
# u'and'
# u'fold'
# u'the'
# u'wonton'
# u'skin'
# u'diagonally'
# u'to'
# u'form'
# u'a'
# u'triangle,'
# u'pressing'
# u'edges'
# u'to'
# u'seal.'
# u'moisten'
# u'one'
# u'of'
# u'the'
# u'bottom'
# u'corners.'
# u'create'
# u'a'
# u'crown'
# u'by'
# u'pulling'
# u'both'
# u'bottom'
# u'corners'
# u'together'
# u'and'
# u'sealing.'
# u'arrange'
# u'the'
# u'rangoon'
# u'on'
# u'the'
# u'baking'
# u'sheet'
# u'and'
# u'lightly'
# u'spray'
# u'with'
# u'cooking'
# u'spray.\nbake'
# u'in'
# u'the'
# u'preheated'
# u'oven'
# u'until'
# u'golden'
# u'brown,'
# u'12'
# u'to'
# u'15'
# u'minutes.\n'
# u'1'
# u'pound'
# u'raw'
# u'shrimp,'
# u'peeled'
# u'and'
# u'deveined\n4'
# u'pounds'
# u'ground'
# u'beef\n1'
# u'tablespoon'
# u'minced'
# u'fresh'
# u'ginger'
# u'root\n1'
# u'shallot,'
# u'minced\n1'
# u'bunch'
# u'green'
# u'onions,'
# u'chopped\n3'
# u'leaves'
# u'napa'
# u'cabbage,'
# u'chopped\n2'
# u'tablespoons'
# u'soy'
# u'sauce\n1'
# u'teaspoon'
# u'asian'
# u'(toasted)'
# u'sesame'
# u'oil\nsalt'
# u'and'
# u'white'
# u'pepper'
# u'to'
# u'taste\n1'
# u'pinch'
# u'white'
# u'sugar\n1'
# u'(10'
# u'ounce)'
# u'package'
# u'round'
# u'gyoza/potsticker'
# u'wrappers\nvegetable'
# u'oil\n1/4'
# u'cup'
# u'water\nplace'
# u'the'
# u'shrimp'
# u'in'
# u'the'
# u'work'
# u'bowl'
# u'of'
# u'a'
# u'food'
# u'processor,'
# u'and'
# u'process'
# u'until'
# u'the'
# u'shrimp'
# u'are'
# u'finely'
# u'ground.'
# u'set'
# u'aside'
# u'in'
# u'a'
# u'large'
# u'bowl.'
# u'working'
# u'in'
# u'batches,'
# u'process'
# u'the'
# u'ground'
# u'beef'
# u'to'
# u'a'
# u'fine'
# u'grind,'
# u'and'
# u'set'
# u'aside'
# u'with'
# u'the'
# u'shrimp.'
# u'combine'
# u'the'
# u'shrimp'
# u'and'
# u'ground'
# u'beef'
# u'with'
# u'ginger,'
# u'shallot,'
# u'green'
# u'onions,'
# u'napa'
# u'cabbage,'
# u'soy'
# u'sauce,'
# u'sesame'
# u'oil,'
# u'salt'
# u'and'
# u'pepper,'
# u'and'
# u'white'
# u'sugar,'
# u'and'
# u'mix'
# u'the'
# u'ingredients'
# u'until'
# u'thoroughly'
# u'combined.\nto'
# u'fill'
# u'the'
# u'pot'
# u'stickers,'
# u'place'
# u'a'
# u'wrapper'
# u'on'
# u'a'
# u'work'
# u'surface'
# u'in'
# u'front'
# u'of'
# u'you,'
# u'and'
# u'place'
# u'a'
# u'scant'
# u'teaspoon'
# u'of'
# u'filling'
# u'in'
# u'the'
# u'center.'
# u'with'
# u'a'
# u'wet'
# u'finger,'
# u'dampen'
# u'the'
# u'edges'
# u'of'
# u'the'
# u'wrapper.'
# u'fold'
# u'the'
# u'dough'
# u'into'
# u'a'
# u'half-moon'
# u'shape,'
# u'enclosing'
# u'the'
# u'filling,'
# u'and'
# u'press'
# u'and'
# u'seal'
# u'to'
# u'remove'
# u'extra'
# u'air'
# u'and'
# u'tightly'
# u'seal'
# u'the'
# u'edges'
# u'together.'
# u"it's"
# u'nice'
# u'to'
# u'fold'
# u'several'
# u'small'
# u'pleats'
# u'in'
# u'the'
# u'top'
# u'half'
# u'of'
# u'the'
# u'wrapper'
# u'for'
# u'a'
# u'traditional'
# u'look'
# u'before'
# u'you'
# u'seal'
# u'in'
# u'the'
# u'filling.'
# u'refrigerate'
# u'the'
# u'filled'
# u'wrappers'
# u'on'
# u'a'
# u'parchment-lined'
# u'baking'
# u'sheet'
# u'while'
# u'you'
# u'finish'
# u'filling'
# u'and'
# u'sealing'
# u'the'
# u'pot'
# u'stickers.\nheat'
# u'the'
# u'oil'
# u'in'
# u'a'
# u'large'
# u'nonstick'
# u'skillet'
# u'with'
# u'a'
# u'lid'
# u'over'
# u'medium'
# u'heat.'
# u'place'
# u'pot'
# u'stickers'
# u'into'
# u'the'
# u'hot'
# u'oil,'
# u'flat'
# u'sides'
# u'down,'
# u'without'
# u'crowding,'
# u'and'
# u'let'
# u'fry'
# u'until'
# u'the'
# u'bottoms'
# u'are'
# u'golden'
# u'brown,'
# u'1'
# u'to'
# u'2'
# u'minutes.'
# u'turn'
# u'the'
# u'dumplings'
# u'over,'
# u'and'
# u'pour'
# u'the'
# u'water'
# u'over'
# u'them.'
# u'cover'
# u'the'
# u'pan'
# u'with'
# u'a'
# u'lid'
# u'and'
# u'let'
# u'the'
# u'dumplings'
# u'steam'
# u'until'
# u'the'
# u'water'
# u'has'
# u'nearly'
# u'evaporated'
# u'and'
# u'the'
# u'dumplings'
# u'have'
# u'begun'
# u'to'
# u'fry'
# u'in'
# u'oil'
# u'again,'
# u'5'
# u'to'
# u'7'
# u'minutes.'
# u'uncover'
# u'the'
# u'skillet,'
# u'and'
# u'let'
# u'the'
# u'pot'
# u'stickers'
# u'cook'
# u'until'
# u'all'
# u'the'
# u'water'
# u'is'
# u'evaporated'
# u'and'
# u'the'
# u'wrapper'
# u'has'
# u'shrunk'
# u'down'
# u'tightly'
# u'onto'
# u'the'
# u'filling,'
# u'another'
# u'2'
# u'to'
# u'3'
# u'minutes.\n'
# u'1'
# u'pound'
# u'ground'
# u'chicken\n1/2'
# u'cup'
# u'dry'
# u'bread'
# u'crumbs\n1'
# u'egg\n1'
# u'tablespoon'
# u'lemon'
# u'juice\n2'
# u'tablespoons'
# u'chopped'
# u'sun-dried'
# u'tomatoes\n1'
# u'tablespoon'
# u'chopped'
# u'fresh'
# u'basil\n3'
# u'teaspoons'
# u'chopped'
# u'fresh'
# u'oregano\nsalt'
# u'and'
# u'pepper'
# u'to'
# u'taste\n2'
# u'ounces'
# u'crumbled'
# u'feta'
# u'cheese\npreheat'
# u'an'
# u'outdoor'
# u'grill'
# u'for'
# u'medium-high'
# u'heat,'
# u'and'
# u'lightly'
# u'oil'
# u'the'
# u'grate.\nmix'
# u'the'
# u'chicken,'
# u'bread'
# u'crumbs,'
# u'egg,'
# u'lemon'
# u'juice,'
# u'sun-dried'
# u'tomatoes,'
# u'basil,'
# u'oregano,'
# u'salt,'
# u'and'
# u'pepper'
# u'together'
# u'in'
# u'a'
# u'bowl;'
# u'form'
# u'the'
# u'mixture'
# u'into'
# u'5'
# u'patties.'
# u'divide'
# u'the'
# u'feta'
# u'cheese'
# u'between'
# u'the'
# u'5'
# u'patties;'
# u'place'
# u'a'
# u'portion'
# u'of'
# u'the'
# u'feta'
# u'cheese'
# u'atop'
# u'each'
# u'patty'
# u'and'
# u'fold'
# u'the'
# u'chicken'
# u'mixture'
# u'around'
# u'the'
# u'cheese'
# u'so'
# u'that'
# u'the'
# u'cheese'
# u'is'
# u'in'
# u'the'
# u'center.\ncook'
# u'on'
# u'the'
# u'preheated'
# u'grill'
# u'until'
# u'no'
# u'longer'
# u'pink'
# u'on'
# u'the'
# u'inside'
# u'and'
# u'the'
# u'juices'
# u'run'
# u'clear,'
# u'5'
# u'to'
# u'7'
# u'minutes'
# u'per'
# u'side.'
# u'an'
# u'instant-read'
# u'thermometer'
# u'inserted'
# u'into'
# u'the'
# u'center'
# u'should'
# u'read'
# u'165'
# u'degrees'
# u'f'
# u'(75'
# u'degrees'
# u'c).\n'
# u'4'
# u'mangos'
# u'-'
# u'peeled,'
# u'seeded,'
# u'and'
# u'diced\n1'
# u'(15'
# u'ounce)'
# u'can'
# u'black'
# u'beans,'
# u'rinsed'
# u'and'
# u'drained\n1'
# u'(10'
# u'ounce)'
# u'can'
# u'white'
# u'shoepeg'
# u'corn,'
# u'drained\n2'
# u'tablespoons'
# u'chopped'
# u'fresh'
# u'cilantro\n1'
# u'lime,'
# u'juiced\nsalt'
# u'and'
# u'pepper'
# u'to'
# u'taste\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nadd'
# u'all'
# u'ingredients'
# u'to'
# u'list\nstir'
# u'the'
# u'diced'
# u'mango,'
# u'black'
# u'beans,'
# u'corn,'
# u'cilantro,'
# u'lime'
# u'juice,'
# u'salt,'
# u'and'
# u'pepper'
# u'together'
# u'in'
# u'a'
# u'bowl.'
# u'chill'
# u'at'
# u'least'
# u'1'
# u'hour'
# u'before'
# u'serving.\n'
# filtered words from 1362 to 1362
# Exception AssertionError: AssertionError() in <bound method InteractiveSession.__del__ of <tensorflow.python.client.session.InteractiveSession object at 0x11ddfe250>> ignored
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-361f20c46b2a> in <module>()
# ----> 1 generated_words = test()
#       2 print(' '.join(generated_words))
#
# <ipython-input-6-b5dcc7e6cfcf> in test(test_feat, model_path, maxlen)
#      19             ctx_shape=ctx_shape)
#      20
# ---> 21     context, generated_words, logit_list, alpha_list = caption_generator.build_generator(maxlen=maxlen)
#      22     saver = tf.train.Saver()
#      23     saver.restore(sess, model_path)
#
# <ipython-input-11-dc29e1de730b> in build_generator(self, maxlen)
#     146
#     147             weighted_context = tf.reduce_sum(tf.squeeze(context) * alpha, 0)
# --> 148             weighted_context = tf.expand_dims(weighted_context, 0)
#     149
#     150             lstm_preactive = tf.matmul(h, self.lstm_U) + x_t + tf.matmul(weighted_context, self.image_encode_W)
#
# /Library/Python/2.7/site-packages/tensorflow/python/ops/gen_array_ops.pyc in expand_dims(input, dim, name)
#     361     dimension of size 1 added.
#     362   """
# --> 363   return _op_def_lib.apply_op("ExpandDims", input=input, dim=dim, name=name)
#     364
#     365
#
# /Library/Python/2.7/site-packages/tensorflow/python/ops/op_def_library.pyc in apply_op(self, op_type_name, name, **keywords)
#     409             values = ops.convert_to_tensor(
#     410                 values, name=input_arg.name, dtype=dtype,
# --> 411                 as_ref=input_arg.is_ref)
#     412           except ValueError:
#     413             # What type does convert_to_tensor think it has?
#
# /Library/Python/2.7/site-packages/tensorflow/python/framework/ops.pyc in convert_to_tensor(value, dtype, name, as_ref)
#     527     for base_type, conversion_func in funcs_at_priority:
#     528       if isinstance(value, base_type):
# --> 529         ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     530         if not isinstance(ret, Tensor):
#     531           raise RuntimeError(
#
# /Library/Python/2.7/site-packages/tensorflow/python/ops/constant_op.pyc in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     176                                          as_ref=False):
#     177   _ = as_ref
# --> 178   return constant(v, dtype=dtype, name=name)
#     179
#     180
#
# /Library/Python/2.7/site-packages/tensorflow/python/ops/constant_op.pyc in constant(value, dtype, shape, name)
#     163   const_tensor = g.create_op(
#     164       "Const", [], [dtype_value.type],
# --> 165       attrs={"value": tensor_value, "dtype": dtype_value}, name=name).outputs[0]
#     166   return const_tensor
#     167
#
# /Library/Python/2.7/site-packages/tensorflow/python/framework/ops.pyc in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes, compute_device)
#    2038     ret = Operation(node_def, self, inputs=inputs, output_types=dtypes,
#    2039                     control_inputs=control_inputs, input_types=input_types,
# -> 2040                     original_op=self._default_original_op, op_def=op_def)
#    2041     if compute_shapes:
#    2042       set_shapes_for_outputs(ret)
#
# /Library/Python/2.7/site-packages/tensorflow/python/framework/ops.pyc in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1044     if not isinstance(g, Graph):
#    1045       raise TypeError("g needs to be a Graph: %s" % g)
# -> 1046     self._node_def = copy.deepcopy(node_def)
#    1047     self._graph = g
#    1048     if inputs is None:
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/copy.pyc in deepcopy(x, memo, _nil)
#     172             copier = getattr(x, "__deepcopy__", None)
#     173             if copier:
# --> 174                 y = copier(memo)
#     175             else:
#     176                 reductor = dispatch_table.get(cls)
#
# /Library/Python/2.7/site-packages/google/protobuf/message.pyc in __deepcopy__(self, memo)
#      69   def __deepcopy__(self, memo=None):
#      70     clone = type(self)()
# ---> 71     clone.MergeFrom(self)
#      72     return clone
#      73
#
# /Library/Python/2.7/site-packages/google/protobuf/internal/python_message.pyc in MergeFrom(self, msg)
#    1249           field_value = field._default_constructor(self)
#    1250           fields[field] = field_value
# -> 1251         field_value.MergeFrom(value)
#    1252       elif field.cpp_type == CPPTYPE_MESSAGE:
#    1253         if value._is_present_in_parent:
#
# /Library/Python/2.7/site-packages/google/protobuf/internal/containers.pyc in MergeFrom(self, other)
#     595   def MergeFrom(self, other):
#     596     for key in other:
# --> 597       self[key].MergeFrom(other[key])
#     598     # self._message_listener.Modified() not required here, because
#     599     # mutations to submessages already propagate.
#
# /Library/Python/2.7/site-packages/google/protobuf/internal/containers.pyc in __getitem__(self, key)
#     544     except KeyError:
#     545       key = self._key_checker.CheckValue(key)
# --> 546       new_element = self._message_descriptor._concrete_class()
#     547       new_element._SetListener(self._message_listener)
#     548       self._values[key] = new_element
#
# /Library/Python/2.7/site-packages/google/protobuf/internal/python_message.pyc in init(self, **kwargs)
#     472     return value
#     473
# --> 474   def init(self, **kwargs):
#     475     self._cached_byte_size = 0
#     476     self._cached_byte_size_dirty = len(kwargs) > 0
#
# KeyboardInterrupt:

# %%
generated_words
# Out:
# [u'4',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup',
#  u'chopped',
#  u'fresh',
#  u'cup']

# %%
annotation_data = pickle.load(open(annotation_path,"rb"))

# %%
print(annotation_data['200744'])
# Out:
# 4 pork chops
# 1 tablespoon butter
# 1/2 cup brown sugar
# 3/4 cup evaporated milk
# 1/4 cup light corn syrup
# 1/4 cup chopped pecans
# In a large skillet over medium-high heat, cook the pork chops until no longer pink in the center, 5 to 7 minutes per side. An instant-read thermometer inserted into the center should read 145 degrees F (63 degrees C).
# Melt the butter in a saucepan; stir the brown sugar into the melted butter until smooth. Add the evaporated milk and stir; bring the mixture to a boil and immediately remove from heat. Stir the corn syrup into the milk mixture; fold the pecans into the sauce. Spoon the sauce over the pork chops to serve.
